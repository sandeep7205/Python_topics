# %% [markdown]
# ## **In last module, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %% [markdown]
# ## Let us read our data first

# %%
# loading csv File
file_path = 'movie_dataset.csv'
df=pd.read_csv(file_path)
df2=pd.read_csv(file_path)

# %%
df.shape
# Out:
# (2888, 20)

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino

# %%
df.tail(10)
# Out:
#       index     budget                                             genres  \
# 2878   2878   20000000                                             Comedy
# 2879   2879   23000000                                 Adventure Thriller
# 2880   2880   54000000                                              Drama
# 2881   2881   25000000                    Action Adventure Fantasy Horror
# 2882   2882   40000000                                    Horror Thriller
# 2883   2883   20000000                            Action Adventure Comedy
# 2884   2884   20000000                     Action Fantasy Horror Thriller
# 2885   2885   25000000                                      Action Comedy
# 2886   2886   44000000                         Action Science Fiction War
# 2887   2887  100000000  Action Adventure Fantasy Science Fiction Thriller
#
#                                                homepage      id  \
# 2878                                                NaN   10073
# 2879                                                NaN     580
# 2880  http://www.sonypictures.com/homevideo/catalog/...    8046
# 2881  http://www.bloodrayne-themovie.com/main/index....  168705
# 2882                                                NaN    9544
# 2883                                                NaN    9760
# 2884                                                NaN   12142
# 2885                      http://www.disastermovie.net/   13805
# 2886                                                NaN    5491
# 2887                                                NaN   14164
#
#                                                keywords original_language  \
# 2878       date diary parents-in-law bridegroom wedding                en
# 2879  shark attack bahamas dying and death aggressio...                en
# 2880  new york mentally disabled kidnapping blackmai...                en
# 2881  vampire vampire hunter based on video game rom...                en
# 2882   race against time psychopath homepage cop doctor                en
# 2883                                                NaN                en
# 2884          detective monster professor island museum                en
# 2885  natural disaster violence mortal danger during...                en
# 2886  based on novel post-apocalyptic dystopia minin...                en
# 2887  karate superhero revenge dragon duringcreditss...                en
#
#                                                overview  popularity  \
# 2878  Spoof of romantic comedies which focuses on a ...   10.098722
# 2879  After another deadly shark attack, Ellen Brody...   12.777008
# 2880  Gigli is ordered to kidnap the psychologically...    9.053456
# 2881  In eighteenth century Romania, Rayne, a dhampi...    7.008216
# 2882  With four corpses on his hands, New York City ...    6.756886
# 2883  When Edward, Peter, Lucy and Susan each follow...    6.064638
# 2884  Edward Carnby is a private investigator specia...    9.292987
# 2885  In DISASTER MOVIE, the filmmaking team behind ...   16.238961
# 2886  In the year 3000, man is no match for the Psyc...    7.891470
# 2887  The young warrior Son Goku sets out on a quest...   21.677732
#
#                                    production_companies  release_date  \
# 2878  [{"name": "Regency Enterprises", "id": 508}, {...         38765
# 2879         [{"name": "Universal Pictures", "id": 33}]         31975
# 2880  [{"name": "City Light Films", "id": 136}, {"na...         37834
# 2881                 [{"name": "Boll KG", "id": 15127}]         38647
# 2882  [{"name": "Milagro Films", "id": 1070}, {"name...         37477
# 2883  [{"name": "Twentieth Century Fox Film Corporat...         39107
# 2884  [{"name": "Boll Kino Beteiligungs GmbH & Co. K...         38380
# 2885  [{"name": "Grosvenor Park Media Ltd.", "id": 2...         39689
# 2886  [{"name": "Franchise Pictures", "id": 1403}, {...         36656
# 2887  [{"name": "Ingenious Film Partners", "id": 289...         39904
#
#        revenue  runtime                                            tagline  \
# 2878  48548426       83                              An Unprotected Comedy
# 2879  51881013       89                          This time, it’s personal.
# 2880   7266209      121                    Life doesn't play by the rules.
# 2881   2405420       95                     Revenge never tasted so sweet.
# 2882  18902015      101                     The last site you'll ever see.
# 2883  86865564       86                     We know it's big. We measured.
# 2884  10442808       96  Can mankind defeat the army of darkness unleas...
# 2885  14109284       87    Your favorite movies are going to be destroyed.
# 2886  21400000      118                               Take Back The Planet
# 2887         0       85                          The legend comes to life.
#
#                      title  vote_average  vote_count  \
# 2878            Date Movie           3.6         222
# 2879     Jaws: The Revenge           3.5         224
# 2880                 Gigli           3.5         104
# 2881            BloodRayne           3.5         118
# 2882            FearDotCom           3.2         105
# 2883            Epic Movie           3.2         326
# 2884     Alone in the Dark           3.1         173
# 2885        Disaster Movie           3.0         240
# 2886     Battlefield Earth           3.0         255
# 2887  Dragonball Evolution           2.9         462
#
#                                                    cast  \
# 2878  Alyson Hannigan Adam Campbell Sophie Monk Jenn...
# 2879  Lorraine Gary Lance Guest Mario Van Peebles Mi...
# 2880  Ben Affleck Jennifer Lopez Justin Bartha Laini...
# 2881  Kristanna Loken Ben Kingsley Michelle Rodrigue...
# 2882  Stephen Dorff Natascha McElhone Stephen Rea Ud...
# 2883  Kal Penn Adam Campbell Jennifer Coolidge Jayma...
# 2884  Christian Slater Tara Reid Stephen Dorff Frank...
# 2885  Matt Lanter Vanessa Lachey Nicole Ari Parker C...
# 2886  John Travolta Barry Pepper Forest Whitaker Kim...
# 2887  Chow Yun-fat Justin Chatwin Joon Park Jamie Ch...
#
#                                                    crew         director
# 2878  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...  Jason Friedberg
# 2879  [{'name': 'John M. Dwyer', 'gender': 2, 'depar...   Joseph Sargent
# 2880  [{'name': 'Gary Frutkoff', 'gender': 2, 'depar...     Martin Brest
# 2881  [{'name': 'Guinevere Turner', 'gender': 1, 'de...         Uwe Boll
# 2882  [{'name': 'Christian Sebaldt', 'gender': 2, 'd...   William Malone
# 2883  [{'name': 'William A. Elliott', 'gender': 0, '...  Jason Friedberg
# 2884  [{'name': 'Uwe Boll', 'gender': 2, 'department...         Uwe Boll
# 2885  [{'name': 'Peck Prior', 'gender': 2, 'departme...  Jason Friedberg
# 2886  [{'name': 'Lynn Stalmaster', 'gender': 2, 'dep...  Roger Christian
# 2887  [{'name': 'James Wong', 'gender': 2, 'departme...       James Wong

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2888 entries, 0 to 2887
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 2888 non-null   int64
#  1   budget                2888 non-null   int64
#  2   genres                2888 non-null   str
#  3   homepage              1259 non-null   str
#  4   id                    2888 non-null   int64
#  5   keywords              2845 non-null   str
#  6   original_language     2888 non-null   str
#  7   overview              2888 non-null   str
#  8   popularity            2888 non-null   float64
#  9   production_companies  2888 non-null   str
#  10  release_date          2888 non-null   int64
#  11  revenue               2888 non-null   int64
#  12  runtime               2888 non-null   int64
#  13  tagline               2730 non-null   str
#  14  title                 2888 non-null   str
#  15  vote_average          2888 non-null   float64
#  16  vote_count            2888 non-null   int64
#  17  cast                  2888 non-null   str
#  18  crew                  2888 non-null   str
#  19  director              2888 non-null   str
# dtypes: float64(2), int64(7), str(11)
# memory usage: 451.4 KB

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe(include='all')
# Out:
#               index        budget  genres                          homepage  \
# count   2888.000000  2.888000e+03    2888                              1259
# unique          NaN           NaN     876                              1239
# top             NaN           NaN  Comedy  http://www.thehungergames.movie/
# freq            NaN           NaN     169                                 4
# mean    1443.500000  4.455166e+07     NaN                               NaN
# std      833.838114  4.543170e+07     NaN                               NaN
# min        0.000000  1.600000e+05     NaN                               NaN
# 25%      721.750000  1.400000e+07     NaN                               NaN
# 50%     1443.500000  3.000000e+07     NaN                               NaN
# 75%     2165.250000  6.000000e+07     NaN                               NaN
# max     2887.000000  3.800000e+08     NaN                               NaN
#
#                    id              keywords original_language  \
# count     2888.000000                  2845              2888
# unique            NaN                  2828                24
# top               NaN  duringcreditsstinger                en
# freq              NaN                     8              2779
# mean     46557.648546                   NaN               NaN
# std      78311.132756                   NaN               NaN
# min          5.000000                   NaN               NaN
# 25%       3599.250000                   NaN               NaN
# 50%      10675.000000                   NaN               NaN
# 75%      49014.000000                   NaN               NaN
# max     417859.000000                   NaN               NaN
#
#                                                  overview   popularity  \
# count                                                2888  2888.000000
# unique                                               2888          NaN
# top     Framed in the 1940s for the double murder of h...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    32.521757
# std                                                   NaN    36.852001
# min                                                   NaN     1.551497
# 25%                                                   NaN    14.294301
# 50%                                                   NaN    23.439766
# 75%                                                   NaN    40.218528
# max                                                   NaN   875.581305
#
#                              production_companies  release_date       revenue  \
# count                                        2888   2888.000000  2.888000e+03
# unique                                       2413           NaN           NaN
# top     [{"name": "Paramount Pictures", "id": 4}]           NaN           NaN
# freq                                           39           NaN           NaN
# mean                                          NaN  37780.700831  1.330831e+08
# std                                           NaN   4234.819093  1.934428e+08
# min                                           NaN   9872.000000  0.000000e+00
# 25%                                           NaN  36353.750000  2.181884e+07
# 50%                                           NaN  38758.000000  6.816994e+07
# 75%                                           NaN  40662.000000  1.601493e+08
# max                                           NaN  42629.000000  2.787965e+09
#
#             runtime                       tagline   title  vote_average  \
# count   2888.000000                          2730    2888   2888.000000
# unique          NaN                          2722    2886           NaN
# top             NaN  There are no clean getaways.  Batman           NaN
# freq            NaN                             2       2           NaN
# mean     110.845914                           NaN     NaN      6.358726
# std       20.045847                           NaN     NaN      0.837566
# min       63.000000                           NaN     NaN      2.900000
# 25%       97.000000                           NaN     NaN      5.800000
# 50%      107.000000                           NaN     NaN      6.400000
# 75%      121.000000                           NaN     NaN      7.000000
# max      248.000000                           NaN     NaN      8.500000
#
#           vote_count                                               cast  \
# count    2888.000000                                               2888
# unique           NaN                                               2871
# top              NaN  William Shatner Leonard Nimoy DeForest Kelley ...
# freq             NaN                                                  6
# mean     1100.020429                                                NaN
# std      1449.607453                                                NaN
# min       100.000000                                                NaN
# 25%       271.000000                                                NaN
# 50%       562.500000                                                NaN
# 75%      1279.250000                                                NaN
# max     13752.000000                                                NaN
#
#                                                      crew          director
# count                                                2888              2888
# unique                                               2888              1234
# top     [{'name': 'Thomas Newman', 'gender': 2, 'depar...  Steven Spielberg
# freq                                                    1                27
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
# Let us get a subset which consists of first 8 rows and first 4 columns
df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1     Marlon Brando Al Pacino James Caan Richard S. ...
# 2     Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3     Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4     John Travolta Samuel L. Jackson Uma Thurman Br...
# ...                                                 ...
# 2883  Kal Penn Adam Campbell Jennifer Coolidge Jayma...
# 2884  Christian Slater Tara Reid Stephen Dorff Frank...
# 2885  Matt Lanter Vanessa Lachey Nicole Ari Parker C...
# 2886  John Travolta Barry Pepper Forest Whitaker Kim...
# 2887  Chow Yun-fat Justin Chatwin Joon Park Jamie Ch...
#
#                                                    crew              director
# 0     [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1     [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2     [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3     [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4     [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
# ...                                                 ...                   ...
# 2883  [{'name': 'William A. Elliott', 'gender': 0, '...       Jason Friedberg
# 2884  [{'name': 'Uwe Boll', 'gender': 2, 'department...              Uwe Boll
# 2885  [{'name': 'Peck Prior', 'gender': 2, 'departme...       Jason Friedberg
# 2886  [{'name': 'Lynn Stalmaster', 'gender': 2, 'dep...       Roger Christian
# 2887  [{'name': 'James Wong', 'gender': 2, 'departme...            James Wong
#
# [2888 rows x 3 columns]

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
# Now let us subset our dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[0:8,['title','budget','revenue']]
# df.loc[50:60,['title','budget','revenue']]
# Out:
#                       title     budget     revenue
# 0  The Shawshank Redemption   25000000    28341469
# 1             The Godfather    6000000   245066411
# 2                  Whiplash    3300000    13092000
# 3                Fight Club   63000000   100853753
# 4              Pulp Fiction    8000000   213928762
# 5             Spirited Away   15000000   274925095
# 6    The Godfather: Part II   13000000    47542841
# 7          Schindler's List   22000000   321365567
# 8           The Dark Knight  185000000  1004558444

# %%
df.loc[:,['title','budget','revenue']]
# Out:
#                          title     budget    revenue
# 0     The Shawshank Redemption   25000000   28341469
# 1                The Godfather    6000000  245066411
# 2                     Whiplash    3300000   13092000
# 3                   Fight Club   63000000  100853753
# 4                 Pulp Fiction    8000000  213928762
# ...                        ...        ...        ...
# 2883                Epic Movie   20000000   86865564
# 2884         Alone in the Dark   20000000   10442808
# 2885            Disaster Movie   25000000   14109284
# 2886         Battlefield Earth   44000000   21400000
# 2887      Dragonball Evolution  100000000          0
#
# [2888 rows x 3 columns]

# %%
df[0:10]
# Out:
#    index     budget                              genres  \
# 0      0   25000000                         Drama Crime
# 1      1    6000000                         Drama Crime
# 2      2    3300000                               Drama
# 3      3   63000000                               Drama
# 4      4    8000000                      Thriller Crime
# 5      5   15000000  Fantasy Adventure Animation Family
# 6      6   13000000                         Drama Crime
# 7      7   22000000                   Drama History War
# 8      8  185000000         Drama Action Crime Thriller
# 9      9   55000000                Comedy Drama Romance
#
#                                        homepage      id  \
# 0                                           NaN     278
# 1                  http://www.thegodfather.com/     238
# 2             http://sonyclassics.com/whiplash/  244786
# 3    http://www.foxmovies.com/movies/fight-club     550
# 4                                           NaN     680
# 5        http://movies.disney.com/spirited-away     129
# 6                                           NaN     240
# 7                http://www.schindlerslist.com/     424
# 8  http://thedarkknight.warnerbros.com/dvdsite/     155
# 9                                           NaN      13
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
# 5  witch parents kids relationship magic twilight...                ja
# 6      italo-american cuba vororte melancholy praise                en
# 7  factory concentration camp hero holocaust worl...                en
# 8  dc comics crime fighter secret identity scarec...                en
# 9  vietnam veteran hippie mentally disabled runni...                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
# 5  A ten year old girl who wanders away from her ...  118.968562
# 6  In the continuing saga of the Corleone crime f...  105.792936
# 7  The true story of how businessman Oskar Schind...  104.469351
# 8  Batman raises the stakes in his war on crime. ...  187.322927
# 9  A man with a low IQ has accomplished great thi...  138.133331
#
#                                 production_companies  release_date  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615
# 5           [{"name": "Studio Ghibli", "id": 10342}]         37092
# 6  [{"name": "Paramount Pictures", "id": 4}, {"na...         27383
# 7  [{"name": "Universal Pictures", "id": 33}, {"n...         34302
# 8  [{"name": "DC Comics", "id": 429}, {"name": "L...         39645
# 9          [{"name": "Paramount Pictures", "id": 4}]         34521
#
#       revenue  runtime                                            tagline  \
# 0    28341469      142  Fear can hold you prisoner. Hope can set you f...
# 1   245066411      175                         An offer you can't refuse.
# 2    13092000      105    The road to greatness can take you to the edge.
# 3   100853753      139                            Mischief. Mayhem. Soap.
# 4   213928762      154  Just because you are a character doesn't mean ...
# 5   274925095      125     The tunnel led Chihiro to a mysterious town...
# 6    47542841      200  I don't feel I have to wipe everybody out, Tom...
# 7   321365567      195    Whoever saves one life, saves the world entire.
# 8  1004558444      152                                    Why So Serious?
# 9   677945399      142  The world will never be the same, once you've ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
# 5             Spirited Away           8.3        3840
# 6    The Godfather: Part II           8.3        3338
# 7          Schindler's List           8.3        4329
# 8           The Dark Knight           8.2       12002
# 9              Forrest Gump           8.2        7927
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
# 5  Rumi Hiiragi Miyu Irino Mari Natsuki Takashi N...
# 6  Al Pacino Robert Duvall Diane Keaton Robert De...
# 7  Liam Neeson Ben Kingsley Ralph Fiennes Carolin...
# 8  Christian Bale Heath Ledger Aaron Eckhart Mich...
# 9  Tom Hanks Robin Wright Gary Sinise Mykelti Wil...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
# 5  [{'name': 'John Lasseter', 'gender': 2, 'depar...        Hayao Miyazaki
# 6  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 7  [{'name': 'John Williams', 'gender': 2, 'depar...      Steven Spielberg
# 8  [{'name': 'Lucinda Syson', 'gender': 1, 'depar...     Christopher Nolan
# 9  [{'name': 'Alan Silvestri', 'gender': 2, 'depa...       Robert Zemeckis

# %%
df[['title','director','genres']]
# Out:
#                          title              director  \
# 0     The Shawshank Redemption        Frank Darabont
# 1                The Godfather  Francis Ford Coppola
# 2                     Whiplash       Damien Chazelle
# 3                   Fight Club         David Fincher
# 4                 Pulp Fiction     Quentin Tarantino
# ...                        ...                   ...
# 2883                Epic Movie       Jason Friedberg
# 2884         Alone in the Dark              Uwe Boll
# 2885            Disaster Movie       Jason Friedberg
# 2886         Battlefield Earth       Roger Christian
# 2887      Dragonball Evolution            James Wong
#
#                                                  genres
# 0                                           Drama Crime
# 1                                           Drama Crime
# 2                                                 Drama
# 3                                                 Drama
# 4                                        Thriller Crime
# ...                                                 ...
# 2883                            Action Adventure Comedy
# 2884                     Action Fantasy Horror Thriller
# 2885                                      Action Comedy
# 2886                         Action Science Fiction War
# 2887  Action Adventure Fantasy Science Fiction Thriller
#
# [2888 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'overview', 'popularity', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='str')

# %% [markdown]
# ## <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'] == 'en'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2883    True
# 2884    True
# 2885    True
# 2886    True
# 2887    True
# Name: original_language, Length: 2888, dtype: bool

# %%
# Boolean Indexing
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino

# %%
english_movies.shape
# Out:
# (2779, 20)

# %%
non_english_movies = df[df['vote_average'] != 9.0]
non_english_movies.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino

# %%
long_movies = df[df['runtime'] > 120]
long_movies[['title','director','runtime']]
# Out:
#                                               title              director  \
# 0                          The Shawshank Redemption        Frank Darabont
# 1                                     The Godfather  Francis Ford Coppola
# 3                                        Fight Club         David Fincher
# 4                                      Pulp Fiction     Quentin Tarantino
# 5                                     Spirited Away        Hayao Miyazaki
# ...                                             ...                   ...
# 2766                                How Do You Know       James L. Brooks
# 2855                                 Batman & Robin       Joel Schumacher
# 2863                        Speed 2: Cruise Control           Jan de Bont
# 2869  In the Name of the King: A Dungeon Siege Tale              Uwe Boll
# 2880                                          Gigli          Martin Brest
#
#       runtime
# 0         142
# 1         175
# 3         139
# 4         154
# 5         125
# ...       ...
# 2766      121
# 2855      125
# 2863      121
# 2869      127
# 2880      121
#
# [754 rows x 3 columns]

# %% [markdown]
# ## Infact we can match conditions for mutliple columns

# %%
long_movies = df[df['vote_average']  > 7.3]
long_movies[['title','director','vote_average']]
# Out:
#                         title               director  vote_average
# 0    The Shawshank Redemption         Frank Darabont           8.5
# 1               The Godfather   Francis Ford Coppola           8.4
# 2                    Whiplash        Damien Chazelle           8.3
# 3                  Fight Club          David Fincher           8.3
# 4                Pulp Fiction      Quentin Tarantino           8.3
# ..                        ...                    ...           ...
# 334           This Is England          Shane Meadows           7.4
# 335               The Verdict           Sidney Lumet           7.4
# 336   The Secret Life of Bees  Gina Prince-Bythewood           7.4
# 337       Fiddler on the Roof         Norman Jewison           7.4
# 338          The Lost Weekend           Billy Wilder           7.4
#
# [339 rows x 3 columns]

# %%
long_movies.tail()
# Out:
#      index    budget         genres  \
# 334    334   2380000    Drama Crime
# 335    335  16000000          Drama
# 336    336  11000000      Adventure
# 337    337   9000000  Drama Romance
# 338    338   1250000          Drama
#
#                                               homepage     id  \
# 334               http://www.thisisenglandmovie.co.uk/  11798
# 335                                                NaN  24226
# 336  http://www.foxsearchlight.com/thesecretlifeofb...  12837
# 337                                                NaN  14811
# 338                                                NaN  28580
#
#                                               keywords original_language  \
# 334  holiday skinhead england vandalism independent...                en
# 335       boston court malpractice alcoholic courtroom                en
# 336                                     woman director                en
# 337  tradition dream musical pogrom mother daughter...                en
# 338  desperation weekend delirium addiction alcoholism                en
#
#                                               overview  popularity  \
# 334  A story about a troubled boy growing up in Eng...    8.395624
# 335  Frank Galvin is a down-on-his luck lawyer, red...    7.980632
# 336  Set in South Carolina in 1964, this is the tal...    7.645979
# 337  This lavishly produced and critically acclaime...    7.623979
# 338  Don Birnam, a long-time alcoholic, has been so...    6.903314
#
#                                   production_companies  release_date  \
# 334  [{"name": "EM Media", "id": 1917}, {"name": "U...         38972
# 335  [{"name": "Twentieth Century Fox Film Corporat...         30293
# 336  [{"name": "Fox Searchlight Pictures", "id": 43...         39708
# 337  [{"name": "United Artists", "id": 60}, {"name"...         26240
# 338                [{"name": "Paramount", "id": 6033}]         16766
#
#       revenue  runtime                                            tagline  \
# 334   8176544      101       Run with the crowd, stand alone, you decide.
# 335  53977250      129  The doctors want to settle, the Church wants t...
# 336  38105395      114  Bring Your Girlfriends, Sisters, Mothers and D...
# 337  83304330      181                                           To Life!
# 338  11000000      101  The screen dares to open the strange and savag...
#
#                        title  vote_average  vote_count  \
# 334          This Is England           7.4         363
# 335              The Verdict           7.4         131
# 336  The Secret Life of Bees           7.4         158
# 337      Fiddler on the Roof           7.4         134
# 338         The Lost Weekend           7.4         112
#
#                                                   cast  \
# 334  Thomas Turgoose Stephen Graham Jo Hartley Andr...
# 335  Paul Newman Charlotte Rampling Jack Warden Jam...
# 336  Dakota Fanning Queen Latifah Jennifer Hudson S...
# 337  Chaim Topol Norma Crane Leonard Frey Molly Pic...
# 338  Ray Milland Jane Wyman Phillip Terry Howard Da...
#
#                                                   crew               director
# 334  [{'name': 'Tessa Ross', 'gender': 1, 'departme...          Shane Meadows
# 335  [{'name': 'Peter C. Frank', 'gender': 2, 'depa...           Sidney Lumet
# 336  [{'name': 'Will Smith', 'gender': 2, 'departme...  Gina Prince-Bythewood
# 337  [{'name': 'John Williams', 'gender': 2, 'depar...         Norman Jewison
# 338  [{'name': 'Billy Wilder', 'gender': 0, 'depart...           Billy Wilder

# %%
(df['vote_average']  > 7.3) & (df['runtime'] > 120)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 2883    False
# 2884    False
# 2885    False
# 2886    False
# 2887    False
# Length: 2888, dtype: bool

# %%
long_english_movies = df[(df['vote_average']  > 7.3) & (df['runtime'] > 120)]
long_english_movies.head()
# Out:
#    index    budget                              genres  \
# 0      0  25000000                         Drama Crime
# 1      1   6000000                         Drama Crime
# 3      3  63000000                               Drama
# 4      4   8000000                      Thriller Crime
# 5      5  15000000  Fantasy Adventure Animation Family
#
#                                      homepage   id  \
# 0                                         NaN  278
# 1                http://www.thegodfather.com/  238
# 3  http://www.foxmovies.com/movies/fight-club  550
# 4                                         NaN  680
# 5      http://movies.disney.com/spirited-away  129
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
# 5  witch parents kids relationship magic twilight...                ja
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
# 5  A ten year old girl who wanders away from her ...  118.968562
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
# 5           [{"name": "Studio Ghibli", "id": 10342}]         37092  274925095
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
# 5      125     The tunnel led Chihiro to a mysterious town...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
# 5             Spirited Away           8.3        3840
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
# 5  Rumi Hiiragi Miyu Irino Mari Natsuki Takashi N...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
# 5  [{'name': 'John Lasseter', 'gender': 2, 'depar...        Hayao Miyazaki

# %%
long_english_movies.shape
# Out:
# (186, 20)

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
df.shape
# Out:
# (2888, 20)

# %% [markdown]
# ## **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
df['runtime']
# Out:
# 0       142
# 1       175
# 2       105
# 3       139
# 4       154
#        ...
# 2883     86
# 2884     96
# 2885     87
# 2886    118
# 2887     85
# Name: runtime, Length: 2888, dtype: int64

# %%
# Add new column which is just half the runtime
df['half_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  ...    revenue  runtime  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]  ...   28341469      142
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...  245066411      175
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...  ...   13092000      105
# 3  [{"name": "Regency Enterprises", "id": 508}, {...  ...  100853753      139
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...  ...  213928762      154
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
# 1                         An offer you can't refuse.
# 2    The road to greatness can take you to the edge.
# 3                            Mischief. Mayhem. Soap.
# 4  Just because you are a character doesn't mean ...
#
#                       title vote_average  vote_count  \
# 0  The Shawshank Redemption          8.5        8205
# 1             The Godfather          8.4        5893
# 2                  Whiplash          8.3        4254
# 3                Fight Club          8.3        9413
# 4              Pulp Fiction          8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director  \
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
#
#   half_runtime
# 0         71.0
# 1         87.5
# 2         52.5
# 3         69.5
# 4         77.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## We can also create a new column by adding two existing columns

# %%
# Creating another new column by subtracting/adding two existing columns
df['movie_profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  ...  runtime  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]  ...      142
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...      175
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...  ...      105
# 3  [{"name": "Regency Enterprises", "id": 508}, {...  ...      139
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...  ...      154
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
# 1                         An offer you can't refuse.
# 2    The road to greatness can take you to the edge.
# 3                            Mischief. Mayhem. Soap.
# 4  Just because you are a character doesn't mean ...
#
#                       title vote_average vote_count  \
# 0  The Shawshank Redemption          8.5       8205
# 1             The Godfather          8.4       5893
# 2                  Whiplash          8.3       4254
# 3                Fight Club          8.3       9413
# 4              Pulp Fiction          8.3       8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director  \
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
#
#   half_runtime movie_profit
# 0         71.0      3341469
# 1         87.5    239066411
# 2         52.5      9792000
# 3         69.5     37853753
# 4         77.0    205928762
#
# [5 rows x 22 columns]

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
# Remove column
df.drop(['id'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage  \
# 0                                         NaN
# 1                http://www.thegodfather.com/
# 2           http://sonyclassics.com/whiplash/
# 3  http://www.foxmovies.com/movies/fight-club
# 4                                         NaN
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date  ...  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600  ...
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  ...
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922  ...
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  ...
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  ...
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title vote_average  vote_count  \
# 0  The Shawshank Redemption          8.5        8205
# 1             The Godfather          8.4        5893
# 2                  Whiplash          8.3        4254
# 3                Fight Club          8.3        9413
# 4              Pulp Fiction          8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director  \
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
#
#   half_runtime  movie_profit
# 0         71.0       3341469
# 1         87.5     239066411
# 2         52.5       9792000
# 3         69.5      37853753
# 4         77.0     205928762
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#              index        budget   popularity  release_date       revenue  \
# count  2888.000000  2.888000e+03  2888.000000   2888.000000  2.888000e+03
# mean   1443.500000  4.455166e+07    32.521757  37780.700831  1.330831e+08
# std     833.838114  4.543170e+07    36.852001   4234.819093  1.934428e+08
# min       0.000000  1.600000e+05     1.551497   9872.000000  0.000000e+00
# 25%     721.750000  1.400000e+07    14.294301  36353.750000  2.181884e+07
# 50%    1443.500000  3.000000e+07    23.439766  38758.000000  6.816994e+07
# 75%    2165.250000  6.000000e+07    40.218528  40662.000000  1.601493e+08
# max    2887.000000  3.800000e+08   875.581305  42629.000000  2.787965e+09
#
#            runtime  vote_average    vote_count  half_runtime  movie_profit
# count  2888.000000   2888.000000   2888.000000   2888.000000  2.888000e+03
# mean    110.845914      6.358726   1100.020429     55.422957  8.853143e+07
# std      20.045847      0.837566   1449.607453     10.022923  1.654285e+08
# min      63.000000      2.900000    100.000000     31.500000 -1.657101e+08
# 25%      97.000000      5.800000    271.000000     48.500000  8.652608e+05
# 50%     107.000000      6.400000    562.500000     53.500000  3.449484e+07
# 75%     121.000000      7.000000   1279.250000     60.500000  1.097184e+08
# max     248.000000      8.500000  13752.000000    124.000000  2.550965e+09

# %% [markdown]
# ## You can drop  multiple columns at once too.

# %%
df.drop(['half_runtime','homepage'],axis=1,inplace=True)

# %%
df.drop(['crew'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast              director  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...        Frank Darabont
# 1  Marlon Brando Al Pacino James Caan Richard S. ...  Francis Ford Coppola
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...       Damien Chazelle
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...         David Fincher
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...     Quentin Tarantino
#
#    movie_profit
# 0       3341469
# 1     239066411
# 2       9792000
# 3      37853753
# 4     205928762

# %% [markdown]
# ## **We can do a lot of basic operations as well**

# %%
# Find the sum of values in a column
df['budget'].sum()
# Out:
# np.int64(128665192296)

# %%
# What if there is a null value
df.loc[:1,'revenue'] = np.nan

# %%
df.iloc[:5]
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#        revenue  runtime                                            tagline  \
# 0          NaN      142  Fear can hold you prisoner. Hope can set you f...
# 1          NaN      175                         An offer you can't refuse.
# 2   13092000.0      105    The road to greatness can take you to the edge.
# 3  100853753.0      139                            Mischief. Mayhem. Soap.
# 4  213928762.0      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast              director  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...        Frank Darabont
# 1  Marlon Brando Al Pacino James Caan Richard S. ...  Francis Ford Coppola
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...       Damien Chazelle
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...         David Fincher
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...     Quentin Tarantino
#
#    movie_profit
# 0       3341469
# 1     239066411
# 2       9792000
# 3      37853753
# 4     205928762

# %%
df.set_index('index', inplace=True)

# %%
df.head()
# Out:
#          budget          genres  \
# index
# 0      25000000     Drama Crime
# 1       6000000     Drama Crime
# 2       3300000           Drama
# 3      63000000           Drama
# 4       8000000  Thriller Crime
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
# 3      support group dual identity nihilism rage and ...                en
# 4          transporter brothel drug dealer boxer massage                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
# 3      A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4      A burger-loving hit man, his philosophical par...  121.463076
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3      [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4      [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#            revenue  runtime  \
# index
# 0              NaN      142
# 1              NaN      175
# 2       13092000.0      105
# 3      100853753.0      139
# 4      213928762.0      154
#
#                                                  tagline  \
# index
# 0      Fear can hold you prisoner. Hope can set you f...
# 1                             An offer you can't refuse.
# 2        The road to greatness can take you to the edge.
# 3                                Mischief. Mayhem. Soap.
# 4      Just because you are a character doesn't mean ...
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
# 3                    Fight Club           8.3        9413
# 4                  Pulp Fiction           8.3        8428
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3      Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4      John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                    director  movie_profit         Capitalized_title
# index
# 0            Frank Darabont       3341469  THE SHAWSHANK REDEMPTION
# 1      Francis Ford Coppola     239066411             THE GODFATHER
# 2           Damien Chazelle       9792000                  WHIPLASH
# 3             David Fincher      37853753                FIGHT CLUB
# 4         Quentin Tarantino     205928762              PULP FICTION

# %%
df.iloc[:3]
# Out:
#          budget       genres  \
# index
# 0      25000000  Drama Crime
# 1       6000000  Drama Crime
# 2       3300000        Drama
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
#
#           revenue  runtime                                            tagline  \
# index
# 0             NaN      142  Fear can hold you prisoner. Hope can set you f...
# 1             NaN      175                         An offer you can't refuse.
# 2      13092000.0      105    The road to greatness can take you to the edge.
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
#
#                    director  movie_profit         Capitalized_title
# index
# 0            Frank Darabont       3341469  THE SHAWSHANK REDEMPTION
# 1      Francis Ford Coppola     239066411             THE GODFATHER
# 2           Damien Chazelle       9792000                  WHIPLASH

# %%
df.loc[[2344,2798]]
# Out:
#           budget                                     genres  \
# index
# 2344   100000000  Thriller Science Fiction Action Adventure
# 2798    20000000                    Horror Mystery Thriller
#
#                                                 keywords original_language  \
# index
# 2344    gorilla space marine space suit revolution chimp                en
# 2798   candy loss of sister mobile phone answering ma...                en
#
#                                                 overview  popularity  \
# index
# 2344   After a spectacular crash-landing on an unchar...   51.188633
# 2798   Several people start receiving voice-mails fro...   12.458131
#
#                                     production_companies  release_date  \
# index
# 2344   [{"name": "Twentieth Century Fox Film Corporat...         37097
# 2798   [{"name": "Intermedia Films", "id": 763}, {"na...         39451
#
#            revenue  runtime                                   tagline  \
# index
# 2344   362211740.0      119  You'll be sorry you were ever born human
# 2798           0.0       87     What will it sound like when you die?
#
#                     title  vote_average  vote_count  \
# index
# 2344   Planet of the Apes           5.6        1243
# 2798      One Missed Call           4.7         171
#
#                                                     cast      director  \
# index
# 2344   Mark Wahlberg Tim Roth Helena Bonham Carter Mi...    Tim Burton
# 2798   Shannyn Sossamon Edward Burns Ana Claudia Tala...  Eric Valette
#
#        movie_profit   Capitalized_title
# index
# 2344      262211740  PLANET OF THE APES
# 2798      -20000000     ONE MISSED CALL

# %%
df.head()
# Out:
#          budget          genres  \
# index
# 0      25000000     Drama Crime
# 1       6000000     Drama Crime
# 2       3300000           Drama
# 3      63000000           Drama
# 4       8000000  Thriller Crime
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
# 3      support group dual identity nihilism rage and ...                en
# 4          transporter brothel drug dealer boxer massage                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
# 3      A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4      A burger-loving hit man, his philosophical par...  121.463076
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3      [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4      [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#            revenue  runtime  \
# index
# 0              NaN      142
# 1              NaN      175
# 2       13092000.0      105
# 3      100853753.0      139
# 4      213928762.0      154
#
#                                                  tagline  \
# index
# 0      Fear can hold you prisoner. Hope can set you f...
# 1                             An offer you can't refuse.
# 2        The road to greatness can take you to the edge.
# 3                                Mischief. Mayhem. Soap.
# 4      Just because you are a character doesn't mean ...
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
# 3                    Fight Club           8.3        9413
# 4                  Pulp Fiction           8.3        8428
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3      Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4      John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                    director  movie_profit
# index
# 0            Frank Darabont       3341469
# 1      Francis Ford Coppola     239066411
# 2           Damien Chazelle       9792000
# 3             David Fincher      37853753
# 4         Quentin Tarantino     205928762

# %%
df['runtime'].sum()
# Out:
# np.int64(320123)

# %%
print(f" The shortest movie length is {df['runtime'].min()}")
print(f" The largest movie length is {df['runtime'].max()}")
# Out:
#  The shortest movie length is 63
#  The largest movie length is 248

# %%
df[df['runtime']== 0.0]
# Out:
# Empty DataFrame
# Columns: [budget, genres, keywords, original_language, overview, popularity, production_companies, release_date, revenue, runtime, tagline, title, vote_average, vote_count, cast, director, movie_profit]
# Index: []

# %% [markdown]
# # **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

to_uppercase("python")
# Out:
# 'PYTHON'

# %%
df['Capitalized_title'] = df['title'].apply(to_uppercase)

# %%
df.head()
# Out:
#          budget          genres  \
# index
# 0      25000000     Drama Crime
# 1       6000000     Drama Crime
# 2       3300000           Drama
# 3      63000000           Drama
# 4       8000000  Thriller Crime
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
# 3      support group dual identity nihilism rage and ...                en
# 4          transporter brothel drug dealer boxer massage                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
# 3      A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4      A burger-loving hit man, his philosophical par...  121.463076
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3      [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4      [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#            revenue  runtime  \
# index
# 0              NaN      142
# 1              NaN      175
# 2       13092000.0      105
# 3      100853753.0      139
# 4      213928762.0      154
#
#                                                  tagline  \
# index
# 0      Fear can hold you prisoner. Hope can set you f...
# 1                             An offer you can't refuse.
# 2        The road to greatness can take you to the edge.
# 3                                Mischief. Mayhem. Soap.
# 4      Just because you are a character doesn't mean ...
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
# 3                    Fight Club           8.3        9413
# 4                  Pulp Fiction           8.3        8428
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3      Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4      John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                    director  movie_profit         Capitalized_title
# index
# 0            Frank Darabont       3341469  THE SHAWSHANK REDEMPTION
# 1      Francis Ford Coppola     239066411             THE GODFATHER
# 2           Damien Chazelle       9792000                  WHIPLASH
# 3             David Fincher      37853753                FIGHT CLUB
# 4         Quentin Tarantino     205928762              PULP FICTION

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)

# %%
df.head()
# Out:
#          budget          genres  \
# index
# 0      25000000     Drama Crime
# 1       6000000     Drama Crime
# 2       3300000           Drama
# 3      63000000           Drama
# 4       8000000  Thriller Crime
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
# 3      support group dual identity nihilism rage and ...                en
# 4          transporter brothel drug dealer boxer massage                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
# 3      A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4      A burger-loving hit man, his philosophical par...  121.463076
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3      [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4      [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#            revenue  runtime  \
# index
# 0              NaN      142
# 1              NaN      175
# 2       13092000.0      105
# 3      100853753.0      139
# 4      213928762.0      154
#
#                                                  tagline  \
# index
# 0      Fear can hold you prisoner. Hope can set you f...
# 1                             An offer you can't refuse.
# 2        The road to greatness can take you to the edge.
# 3                                Mischief. Mayhem. Soap.
# 4      Just because you are a character doesn't mean ...
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
# 3                    Fight Club           8.3        9413
# 4                  Pulp Fiction           8.3        8428
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3      Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4      John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                    director  movie_profit         Capitalized_title  \
# index
# 0            Frank Darabont       3341469  THE SHAWSHANK REDEMPTION
# 1      Francis Ford Coppola     239066411             THE GODFATHER
# 2           Damien Chazelle       9792000                  WHIPLASH
# 3             David Fincher      37853753                FIGHT CLUB
# 4         Quentin Tarantino     205928762              PULP FICTION
#
#         new_profit
# index
# 0              NaN
# 1              NaN
# 2        9792000.0
# 3       37853753.0
# 4      205928762.0

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)
# Out:
#          budget                              genres  \
# index
# 1050   31115000               Drama History Romance
# 136     4000000                   Drama Romance War
# 19     30000000                         Drama Crime
# 104    15000000         Adventure Drama History War
# 20      2000000                        Action Drama
# ...         ...                                 ...
# 2381   20000000          Family Animation Adventure
# 1840   20000000  Adventure Fantasy Animation Family
# 854      858000              Animation Drama Family
# 662    12300000          Animation Adventure Family
# 899    30000000                    Animation Family
#
#                                                 keywords original_language  \
# index
# 1050   ancient rome historical figure cleopatra juliu...                en
# 136    life and death civil war southern usa loss of ...                en
# 19     life and death corruption street gang rape sad...                en
# 104            cairo arabian world war i horse jerusalem                en
# 20                    japan samurai peasant looting rice                ja
# ...                                                  ...               ...
# 2381             river musical tiger village feral child                en
# 1840                                           animation                en
# 854    forest coming of age best friend loss of loved...                en
# 662    vulkan loss of mother tyrannosaurus rex earthq...                en
# 899    owl tiger aftercreditsstinger duringcreditssti...                en
#
#                                                 overview  popularity  \
# index
# 1050   Historical epic. The triumphs and tragedy of t...   13.244365
# 136    An American classic in which a manipulative wo...   48.982550
# 19     A former Prohibition-era Jewish gangster retur...   49.336397
# 104    An epic about British officer T.E. Lawrence's ...   41.286336
# 20     A samurai answers a village's request for prot...   39.756748
# ...                                                  ...         ...
# 2381   Mowgli, missing the jungle and his old friends...   19.819893
# 1840   The classic tale of 'Peter Pan' continues in D...   15.341196
# 854    Bambi's tale unfolds from season to season as ...   47.651878
# 662    An orphaned brontosaurus named Littlefoot sets...   28.670193
# 899    During an ordinary day in Hundred Acre Wood, W...   19.143721
#
#                                     production_companies  release_date  \
# index
# 1050   [{"name": "Twentieth Century Fox Film Corporat...         23174
# 136    [{"name": "Selznick International Pictures", "...         14594
# 19     [{"name": "Warner Bros.", "id": 6194}, {"name"...         30728
# 104     [{"name": "Horizon Pictures (II)", "id": 11356}]         22990
# 20                 [{"name": "Toho Company", "id": 882}]         19840
# ...                                                  ...           ...
# 2381   [{"name": "Walt Disney Pictures", "id": 2}, {"...         37659
# 1840   [{"name": "Walt Disney Pictures", "id": 2}, {"...         37301
# 854    [{"name": "Walt Disney Productions", "id": 3166}]         15567
# 662    [{"name": "Lucasfilm", "id": 1}, {"name": "Uni...         32465
# 899    [{"name": "Walt Disney Pictures", "id": 2}, {"...         40646
#
#            revenue  runtime  \
# index
# 1050    71000000.0      248
# 136    400176459.0      238
# 19             0.0      229
# 104     69995385.0      216
# 20        271841.0      207
# ...            ...      ...
# 2381   135680000.0       72
# 1840   109862682.0       72
# 854    267447150.0       70
# 662     84460846.0       69
# 899     14460000.0       63
#
#                                                  tagline  \
# index
# 1050   The motion picture the world has been waiting ...
# 136                    The greatest romance of all time!
# 19     Crime, passion and lust for power - Sergio Leo...
# 104                                                  NaN
# 20     The Mighty Warriors Who Became the Seven Natio...
# ...                                                  ...
# 2381                                Feel the jungle beat
# 1840                               The Classic Continues
# 854                                  A great love story.
# 662                             A new adventure is born.
# 899                                             Oh Pooh.
#
#                              title  vote_average  vote_count  \
# index
# 1050                     Cleopatra           6.7         146
# 136             Gone with the Wind           7.7         970
# 19     Once Upon a Time in America           8.2        1069
# 104             Lawrence of Arabia           7.8         851
# 20                   Seven Samurai           8.2         878
# ...                            ...           ...         ...
# 2381             The Jungle Book 2           5.6         269
# 1840          Return to Never Land           6.1         290
# 854                          Bambi           6.8        1405
# 662           The Land Before Time           7.0         640
# 899                Winnie the Pooh           6.8         258
#
#                                                     cast  \
# index
# 1050   Elizabeth Taylor Richard Burton Rex Harrison R...
# 136    Vivien Leigh Clark Gable Olivia de Havilland T...
# 19     Robert De Niro James Woods Elizabeth McGovern ...
# 104    Peter O'Toole Alec Guinness Anthony Quinn Jack...
# 20     Toshir\u014d Mifune Takashi Shimura Yoshio Ina...
# ...                                                  ...
# 2381   John Goodman Haley Joel Osment Mae Whitman Con...
# 1840   Harriet Owen Blayne Weaver Jeff Bennett Kath S...
# 854    Donnie Dunagan Peter Behn Stan Alexander Cammi...
# 662    Gabriel Damon Candace Hutson Judith Barsi Will...
# 899    Jim Cummings Travis Oates Bud Luckey Craig Fer...
#
#                    director  movie_profit            Capitalized_title  \
# index
# 1050   Joseph L. Mankiewicz      39885000                    CLEOPATRA
# 136          Victor Fleming     396176459           GONE WITH THE WIND
# 19             Sergio Leone     -30000000  ONCE UPON A TIME IN AMERICA
# 104              David Lean      54995385           LAWRENCE OF ARABIA
# 20           Akira Kurosawa      -1728159                SEVEN SAMURAI
# ...                     ...           ...                          ...
# 2381        Steve Trenbirth     115680000            THE JUNGLE BOOK 2
# 1840             Robin Budd      89862682         RETURN TO NEVER LAND
# 854              David Hand     266589150                        BAMBI
# 662               Don Bluth      72160846         THE LAND BEFORE TIME
# 899        Stephen Anderson     -15540000              WINNIE THE POOH
#
#         new_profit
# index
# 1050    39885000.0
# 136    396176459.0
# 19             NaN
# 104     54995385.0
# 20      -1728159.0
# ...            ...
# 2381   115680000.0
# 1840    89862682.0
# 854    266589150.0
# 662     72160846.0
# 899    -15540000.0
#
# [2888 rows x 19 columns]

# %%
# We can also sort by the combination of two columns
df.sort_values(['vote_count','new_profit'], ascending=[False,True]).head()
# Out:
#           budget                                             genres  \
# index
# 22     160000000  Action Thriller Science Fiction Mystery Adventure
# 8      185000000                        Drama Action Crime Thriller
# 436    237000000           Action Adventure Fantasy Science Fiction
# 262    220000000                   Science Fiction Action Adventure
# 261     58000000                            Action Adventure Comedy
#
#                                                 keywords original_language  \
# index
# 22     loss of lover dream kidnapping sleep subconsci...                en
# 8      dc comics crime fighter secret identity scarec...                en
# 436    culture clash future space war space colony so...                en
# 262    new york shield marvel comic superhero based o...                en
# 261    anti hero mercenary marvel comic superhero bas...                en
#
#                                                 overview  popularity  \
# index
# 22     Cobb, a skilled thief who commits corporate es...  167.583710
# 8      Batman raises the stakes in his war on crime. ...  187.322927
# 436    In the 22nd century, a paraplegic Marine is di...  150.437577
# 262    When an unexpected enemy emerges and threatens...  144.448633
# 261    Deadpool tells the origin story of former Spec...  514.569956
#
#                                     production_companies  release_date  \
# index
# 22     [{"name": "Legendary Pictures", "id": 923}, {"...         40373
# 8      [{"name": "DC Comics", "id": 429}, {"name": "L...         39645
# 436    [{"name": "Ingenious Film Partners", "id": 289...         40157
# 262    [{"name": "Paramount Pictures", "id": 4}, {"na...         41024
# 261    [{"name": "Twentieth Century Fox Film Corporat...         42409
#
#             revenue  runtime                                  tagline  \
# index
# 22     8.255328e+08      148     Your mind is the scene of the crime.
# 8      1.004558e+09      152                          Why So Serious?
# 436    2.787965e+09      162              Enter the World of Pandora.
# 262    1.519558e+09      143                  Some assembly required.
# 261    7.831130e+08      108  Witness the beginning of a happy ending
#
#                  title  vote_average  vote_count  \
# index
# 22           Inception           8.1       13752
# 8      The Dark Knight           8.2       12002
# 436             Avatar           7.2       11800
# 262       The Avengers           7.4       11776
# 261           Deadpool           7.4       10995
#
#                                                     cast           director  \
# index
# 22     Leonardo DiCaprio Joseph Gordon-Levitt Ellen P...  Christopher Nolan
# 8      Christian Bale Heath Ledger Aaron Eckhart Mich...  Christopher Nolan
# 436    Sam Worthington Zoe Saldana Sigourney Weaver S...      James Cameron
# 262    Robert Downey Jr. Chris Evans Mark Ruffalo Chr...        Joss Whedon
# 261    Ryan Reynolds Morena Baccarin Ed Skrein T.J. M...         Tim Miller
#
#        movie_profit Capitalized_title    new_profit
# index
# 22        665532764         INCEPTION  6.655328e+08
# 8         819558444   THE DARK KNIGHT  8.195584e+08
# 436      2550965087            AVATAR  2.550965e+09
# 262      1299557910      THE AVENGERS  1.299558e+09
# 261       725112979          DEADPOOL  7.251130e+08

# %% [markdown]
# # <b>Let us explore some datetime operations and functions

# %% [markdown]
# Directive
#
# * #### <b>%a</b>	Weekday as locale’s abbreviated name.	Sun, Mon, …, Sat (en_US)
# So, Mo, …, Sa (de_DE)
# * #### <b>%A</b>	Weekday as locale’s full name.	Sunday, Monday, …, Saturday (en_US)
# Sonntag, Montag, …, Samstag (de_DE)
# * #### <b>%w</b>	Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.	0, 1, 2, 3, 4, 5, 6
# * #### <b>%d</b>	Day of the month as a zero-padded decimal number.	01, 02, …, 31
# * #### <b>%b</b>	Month as locale’s abbreviated name.	Jan, Feb, …, Dec (en_US)
# Jan, Feb, …, Dez (de_DE)
# * #### <b>%B</b>	Month as locale’s full name.	January, February, …, December (en_US)
# Januar, Februar, …, Dezember (de_DE)
# * #### <b>%m</b>	Month as a zero-padded decimal number.	01, 02 … 12
# * #### <b>%y</b>	Year without century as a zero-padded decimal number.	01, 02, … 99
# * #### <b>%Y</b>	Year with century as a decimal number.	0001, 0002, … , 9999
# * #### <b>%H</b>	Hour (24-hour clock) as a zero-padded decimal number.	01, 02, … , 23
# * #### <b>%I</b>	Hour (12-hour clock) as a zero-padded decimal number.	01, 02, … , 12
# * #### <b>%p</b>	Locale’s equivalent of either AM or PM.	AM, PM (en_US)
# am, pm (de_DE)
# * #### <b>%M</b>	Minute as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%S</b>	Second as a zero-padded decimal number.	01, 02, … , 59
# * #### <b>%f</b>	Microsecond as a decimal number, zero-padded on the left.	000000, 000001, …, 999999

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2888 entries, 0 to 2887
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                2888 non-null   int64
#  1   genres                2888 non-null   str
#  2   keywords              2845 non-null   str
#  3   original_language     2888 non-null   str
#  4   overview              2888 non-null   str
#  5   popularity            2888 non-null   float64
#  6   production_companies  2888 non-null   str
#  7   release_date          2888 non-null   int64
#  8   revenue               2886 non-null   float64
#  9   runtime               2888 non-null   int64
#  10  tagline               2730 non-null   str
#  11  title                 2888 non-null   str
#  12  vote_average          2888 non-null   float64
#  13  vote_count            2888 non-null   int64
#  14  cast                  2888 non-null   str
#  15  director              2888 non-null   str
#  16  movie_profit          2888 non-null   int64
#  17  Capitalized_title     2888 non-null   str
#  18  new_profit            2691 non-null   float64
# dtypes: float64(4), int64(5), str(10)
# memory usage: 428.8 KB

# %%
df['release_date'][0:5]
# Out:
# index
# 0    34600
# 1    26372
# 2    41922
# 3    36448
# 4    34615
# Name: release_date, dtype: int64

# %%
# Importing datetime modules
from datetime import datetime, timedelta
from datetime import date

base_date = datetime(1899, 12, 31)

# %% [markdown]
# ## <code>strptime</code> means string parser, this will convert a string format to datetime.
#
# ## <code>strftime</code> means string formatter, this will format a datetime object to string format.

# %%
df['release_date'][0:5]
# Out:
# index
# 0    34600
# 1    26372
# 2    41922
# 3    36448
# 4    34615
# Name: release_date, dtype: int64

# %%
# df['new_release_date'] = pd.to_datetime(df['release_date'].astype(int), unit='D', origin='1899-12-31')

df['new_release_date'] = df['release_date'].apply(
    lambda x: base_date + timedelta(days=int(x))
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2888 entries, 0 to 2887
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                2888 non-null   int64
#  1   genres                2888 non-null   str
#  2   keywords              2845 non-null   str
#  3   original_language     2888 non-null   str
#  4   overview              2888 non-null   str
#  5   popularity            2888 non-null   float64
#  6   production_companies  2888 non-null   str
#  7   release_date          2888 non-null   int64
#  8   revenue               2886 non-null   float64
#  9   runtime               2888 non-null   int64
#  10  tagline               2730 non-null   str
#  11  title                 2888 non-null   str
#  12  vote_average          2888 non-null   float64
#  13  vote_count            2888 non-null   int64
#  14  cast                  2888 non-null   str
#  15  director              2888 non-null   str
#  16  movie_profit          2888 non-null   int64
#  17  Capitalized_title     2888 non-null   str
#  18  new_profit            2691 non-null   float64
#  19  new_release_date      2888 non-null   datetime64[s]
# dtypes: datetime64[s](1), float64(4), int64(5), str(10)
# memory usage: 451.4 KB

# %%
df.head()
# Out:
#          budget          genres  \
# index
# 0      25000000     Drama Crime
# 1       6000000     Drama Crime
# 2       3300000           Drama
# 3      63000000           Drama
# 4       8000000  Thriller Crime
#
#                                                 keywords original_language  \
# index
# 0      prison corruption police brutality prison cell...                en
# 1      italy love at first sight loss of father patri...                en
# 2      jazz obsession conservatory music teacher new ...                en
# 3      support group dual identity nihilism rage and ...                en
# 4          transporter brothel drug dealer boxer massage                en
#
#                                                 overview  popularity  \
# index
# 0      Framed in the 1940s for the double murder of h...  136.747729
# 1      Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2      Under the direction of a ruthless instructor, ...  192.528841
# 3      A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4      A burger-loving hit man, his philosophical par...  121.463076
#
#                                     production_companies  release_date  \
# index
# 0      [{"name": "Castle Rock Entertainment", "id": 97}]         34600
# 1      [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2      [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3      [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 4      [{"name": "Miramax Films", "id": 14}, {"name":...         34615
#
#            revenue  runtime  \
# index
# 0              NaN      142
# 1              NaN      175
# 2       13092000.0      105
# 3      100853753.0      139
# 4      213928762.0      154
#
#                                                  tagline  \
# index
# 0      Fear can hold you prisoner. Hope can set you f...
# 1                             An offer you can't refuse.
# 2        The road to greatness can take you to the edge.
# 3                                Mischief. Mayhem. Soap.
# 4      Just because you are a character doesn't mean ...
#
#                           title  vote_average  vote_count  \
# index
# 0      The Shawshank Redemption           8.5        8205
# 1                 The Godfather           8.4        5893
# 2                      Whiplash           8.3        4254
# 3                    Fight Club           8.3        9413
# 4                  Pulp Fiction           8.3        8428
#
#                                                     cast  \
# index
# 0      Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1      Marlon Brando Al Pacino James Caan Richard S. ...
# 2      Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3      Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4      John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                    director  movie_profit         Capitalized_title  \
# index
# 0            Frank Darabont       3341469  THE SHAWSHANK REDEMPTION
# 1      Francis Ford Coppola     239066411             THE GODFATHER
# 2           Damien Chazelle       9792000                  WHIPLASH
# 3             David Fincher      37853753                FIGHT CLUB
# 4         Quentin Tarantino     205928762              PULP FICTION
#
#         new_profit new_release_date
# index
# 0              NaN       1994-09-24
# 1              NaN       1972-03-15
# 2        9792000.0       2014-10-11
# 3       37853753.0       1999-10-16
# 4      205928762.0       1994-10-09

# %%
df['new_release_date'][0]
# Out:
# Timestamp('1994-09-24 00:00:00')

# %%
# Month year date
print(df['new_release_date'][0].month)
print(df['new_release_date'][0].year)
print(df['new_release_date'][0].day)
print(df['new_release_date'][0].hour)
print(df['new_release_date'][0].minute)
# Out:
# 9
# 1994
# 24
# 0
# 0

# %%
print(date.today())
print(datetime.now())
# Out:
# 2026-07-17
# 2026-07-17 01:05:49.275573

# %%
datetime.now() + 1

# %%
# Some operations we can do on datetime
from datetime import timedelta
print(date.today())
print(date.today() - timedelta(days=1))
print(datetime.now() + timedelta(hours=5.5))
print(datetime.now() + timedelta(seconds=60))
# Out:
# 2026-07-17
# 2026-07-16
# 2026-07-17 06:35:57.062563
# 2026-07-17 01:06:57.062640

# %%
print(df['new_release_date'][0])
print(df['new_release_date'][5])
# Out:
# 1994-09-24 00:00:00
# 2001-07-21 00:00:00

# %%
# Difference in two datetime
time_delta=df['new_release_date'][0]-df['new_release_date'][5]
time_delta
# Out:
# Timedelta('-2492 days +00:00:00')

# %%
type(time_delta)
# Out:
# pandas.Timedelta

# %%
time_delta.total_seconds()
# Out:
# -215308800.0

# %%
t1 = pd.to_datetime('1/1/2015 01:00')
t2 = pd.to_datetime('1/1/2015 03:30')

print(pd.Timedelta(t2 - t1).seconds / 3600.0)
# Out:
# 2.5

# %% [markdown]
# # **Let's explore the unique and missing values**
#
# * ### <code>unique()</code>
# * ### <code>nunique()</code>
# * ### <code>value_counts()</code>
# * ### <code>isnull()</code>
# * ### <code>fillna()</code>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2888 entries, 0 to 2887
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                2888 non-null   int64
#  1   genres                2888 non-null   str
#  2   keywords              2845 non-null   str
#  3   original_language     2888 non-null   str
#  4   overview              2888 non-null   str
#  5   popularity            2888 non-null   float64
#  6   production_companies  2888 non-null   str
#  7   release_date          2888 non-null   int64
#  8   revenue               2886 non-null   float64
#  9   runtime               2888 non-null   int64
#  10  tagline               2730 non-null   str
#  11  title                 2888 non-null   str
#  12  vote_average          2888 non-null   float64
#  13  vote_count            2888 non-null   int64
#  14  cast                  2888 non-null   str
#  15  director              2888 non-null   str
#  16  movie_profit          2888 non-null   int64
#  17  Capitalized_title     2888 non-null   str
#  18  new_profit            2691 non-null   float64
#  19  new_release_date      2888 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(4), int64(5), str(10)
# memory usage: 451.4 KB

# %%
# Find the list of unique values in a column
list(df['original_language'].unique())
# Out:
# ['en',
#  'ja',
#  'it',
#  'pt',
#  'ko',
#  'de',
#  'da',
#  'fr',
#  'es',
#  'he',
#  'fa',
#  'te',
#  'id',
#  'hi',
#  'ro',
#  'zh',
#  'nl',
#  'cn',
#  'pl',
#  'xx',
#  'th',
#  'nb',
#  'ru',
#  'no']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()
# Out:
# 24

# %%
# Give the counts of each category of a variable
df['original_language'].value_counts()
# Out:
# original_language
# en    2779
# fr      27
# es      13
# ja      11
# de      10
# zh       8
# it       6
# ko       5
# cn       5
# da       4
# pt       3
# fa       2
# id       2
# th       2
# ru       2
# he       1
# te       1
# hi       1
# ro       1
# nl       1
# pl       1
# xx       1
# nb       1
# no       1
# Name: count, dtype: int64

# %%
# Does not make much sense to use value_counts for a numeric variable
df.runtime.value_counts()
# Out:
# runtime
# 100    91
# 98     77
# 106    71
# 105    68
# 95     68
#        ..
# 70      1
# 63      1
# 248     1
# 187     1
# 75      1
# Name: count, Length: 127, dtype: int64

# %%
# Returns a series of booleans if a column value contains nulls
df2['homepage'].isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2883     True
# 2884     True
# 2885    False
# 2886     True
# 2887     True
# Name: homepage, Length: 2888, dtype: bool

# %%
df2[~df2['homepage'].isnull()]
# Out:
#       index    budget                              genres  \
# 1         1   6000000                         Drama Crime
# 2         2   3300000                               Drama
# 3         3  63000000                               Drama
# 5         5  15000000  Fantasy Adventure Animation Family
# 7         7  22000000                   Drama History War
# ...     ...       ...                                 ...
# 2875   2875  16000000     Thriller Action Science Fiction
# 2876   2876  30000000                              Comedy
# 2880   2880  54000000                               Drama
# 2881   2881  25000000     Action Adventure Fantasy Horror
# 2885   2885  25000000                       Action Comedy
#
#                                                homepage      id  \
# 1                          http://www.thegodfather.com/     238
# 2                     http://sonyclassics.com/whiplash/  244786
# 3            http://www.foxmovies.com/movies/fight-club     550
# 5                http://movies.disney.com/spirited-away     129
# 7                        http://www.schindlerslist.com/     424
# ...                                                 ...     ...
# 2875                    http://www.leftbehindmovie.com/  218043
# 2876                    http://www.meetthespartans.com/    7278
# 2880  http://www.sonypictures.com/homevideo/catalog/...    8046
# 2881  http://www.bloodrayne-themovie.com/main/index....  168705
# 2885                      http://www.disastermovie.net/   13805
#
#                                                keywords original_language  \
# 1     italy love at first sight loss of father patri...                en
# 2     jazz obsession conservatory music teacher new ...                en
# 3     support group dual identity nihilism rage and ...                en
# 5     witch parents kids relationship magic twilight...                ja
# 7     factory concentration camp hero holocaust worl...                en
# ...                                                 ...               ...
# 2875             airplane the rapture remake pilot hero                en
# 2876                 fight queen penguin black hole men                en
# 2880  new york mentally disabled kidnapping blackmai...                en
# 2881  vampire vampire hunter based on video game rom...                en
# 2885  natural disaster violence mortal danger during...                en
#
#                                                overview  popularity  \
# 1     Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2     Under the direction of a ruthless instructor, ...  192.528841
# 3     A ticking-time-bomb insomniac and a slippery s...  146.757391
# 5     A ten year old girl who wanders away from her ...  118.968562
# 7     The true story of how businessman Oskar Schind...  104.469351
# ...                                                 ...         ...
# 2875  A small group of survivors are left behind aft...   33.452469
# 2876  From the creators of Scary Movie and Date Movi...   10.608998
# 2880  Gigli is ordered to kidnap the psychologically...    9.053456
# 2881  In eighteenth century Romania, Rayne, a dhampi...    7.008216
# 2885  In DISASTER MOVIE, the filmmaking team behind ...   16.238961
#
#                                    production_companies  release_date  \
# 1     [{"name": "Paramount Pictures", "id": 4}, {"na...         26372
# 2     [{"name": "Bold Films", "id": 2266}, {"name": ...         41922
# 3     [{"name": "Regency Enterprises", "id": 508}, {...         36448
# 5              [{"name": "Studio Ghibli", "id": 10342}]         37092
# 7     [{"name": "Universal Pictures", "id": 33}, {"n...         34302
# ...                                                 ...           ...
# 2875  [{"name": "Stoney Lake Entertainment", "id": 1...         41915
# 2876  [{"name": "Regency Enterprises", "id": 508}, {...         39471
# 2880  [{"name": "City Light Films", "id": 136}, {"na...         37834
# 2881                 [{"name": "Boll KG", "id": 15127}]         38647
# 2885  [{"name": "Grosvenor Park Media Ltd.", "id": 2...         39689
#
#         revenue  runtime                                          tagline  \
# 1     245066411      175                       An offer you can't refuse.
# 2      13092000      105  The road to greatness can take you to the edge.
# 3     100853753      139                          Mischief. Mayhem. Soap.
# 5     274925095      125   The tunnel led Chihiro to a mysterious town...
# 7     321365567      195  Whoever saves one life, saves the world entire.
# ...         ...      ...                                              ...
# 2875   19682924      110                                   The End Begins
# 2876   84646831       84         The Bigger the Hit, The Harder They Fall
# 2880    7266209      121                  Life doesn't play by the rules.
# 2881    2405420       95                   Revenge never tasted so sweet.
# 2885   14109284       87  Your favorite movies are going to be destroyed.
#
#                   title  vote_average  vote_count  \
# 1         The Godfather           8.4        5893
# 2              Whiplash           8.3        4254
# 3            Fight Club           8.3        9413
# 5         Spirited Away           8.3        3840
# 7      Schindler's List           8.3        4329
# ...                 ...           ...         ...
# 2875        Left Behind           3.7         392
# 2876  Meet the Spartans           3.7         359
# 2880              Gigli           3.5         104
# 2881         BloodRayne           3.5         118
# 2885     Disaster Movie           3.0         240
#
#                                                    cast  \
# 1     Marlon Brando Al Pacino James Caan Richard S. ...
# 2     Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3     Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 5     Rumi Hiiragi Miyu Irino Mari Natsuki Takashi N...
# 7     Liam Neeson Ben Kingsley Ralph Fiennes Carolin...
# ...                                                 ...
# 2875  Nicolas Cage Chad Michael Murray Lea Thompson ...
# 2876  Sean Maguire Carmen Electra Ken Davitian Kevin...
# 2880  Ben Affleck Jennifer Lopez Justin Bartha Laini...
# 2881  Kristanna Loken Ben Kingsley Michelle Rodrigue...
# 2885  Matt Lanter Vanessa Lachey Nicole Ari Parker C...
#
#                                                    crew              director
# 1     [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2     [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3     [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 5     [{'name': 'John Lasseter', 'gender': 2, 'depar...        Hayao Miyazaki
# 7     [{'name': 'John Williams', 'gender': 2, 'depar...      Steven Spielberg
# ...                                                 ...                   ...
# 2875  [{'name': 'Jack Green', 'gender': 2, 'departme...         Vic Armstrong
# 2876  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...       Jason Friedberg
# 2880  [{'name': 'Gary Frutkoff', 'gender': 2, 'depar...          Martin Brest
# 2881  [{'name': 'Guinevere Turner', 'gender': 1, 'de...              Uwe Boll
# 2885  [{'name': 'Peck Prior', 'gender': 2, 'departme...       Jason Friedberg
#
# [1259 rows x 20 columns]

# %%
# Lets fill the missing values with the value -999
df2['homepage'].fillna('Not Present',inplace = True)
# Out:
# C:\Users\Sandeep Kumar Mishra\AppData\Local\Temp\ipykernel_11820\1301152528.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df2['homepage'].fillna('Not Present',inplace = True)
# 0                                      Not Present
# 1                     http://www.thegodfather.com/
# 2                http://sonyclassics.com/whiplash/
# 3       http://www.foxmovies.com/movies/fight-club
# 4                                      Not Present
#                            ...
# 2883                                   Not Present
# 2884                                   Not Present
# 2885                 http://www.disastermovie.net/
# 2886                                   Not Present
# 2887                                   Not Present
# Name: homepage, Length: 2888, dtype: str

# %%
df.head()
# Out:
#    index    budget          genres  \
# 0      0  25000000     Drama Crime
# 1      1   6000000     Drama Crime
# 2      2   3300000           Drama
# 3      3  63000000           Drama
# 4      4   8000000  Thriller Crime
#
#                                      homepage      id  \
# 0                                         NaN     278
# 1                http://www.thegodfather.com/     238
# 2           http://sonyclassics.com/whiplash/  244786
# 3  http://www.foxmovies.com/movies/fight-club     550
# 4                                         NaN     680
#
#                                             keywords original_language  \
# 0  prison corruption police brutality prison cell...                en
# 1  italy love at first sight loss of father patri...                en
# 2  jazz obsession conservatory music teacher new ...                en
# 3  support group dual identity nihilism rage and ...                en
# 4      transporter brothel drug dealer boxer massage                en
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...  136.747729
# 1  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 2  Under the direction of a ruthless instructor, ...  192.528841
# 3  A ticking-time-bomb insomniac and a slippery s...  146.757391
# 4  A burger-loving hit man, his philosophical par...  121.463076
#
#                                 production_companies  release_date    revenue  \
# 0  [{"name": "Castle Rock Entertainment", "id": 97}]         34600   28341469
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...         26372  245066411
# 2  [{"name": "Bold Films", "id": 2266}, {"name": ...         41922   13092000
# 3  [{"name": "Regency Enterprises", "id": 508}, {...         36448  100853753
# 4  [{"name": "Miramax Films", "id": 14}, {"name":...         34615  213928762
#
#    runtime                                            tagline  \
# 0      142  Fear can hold you prisoner. Hope can set you f...
# 1      175                         An offer you can't refuse.
# 2      105    The road to greatness can take you to the edge.
# 3      139                            Mischief. Mayhem. Soap.
# 4      154  Just because you are a character doesn't mean ...
#
#                       title  vote_average  vote_count  \
# 0  The Shawshank Redemption           8.5        8205
# 1             The Godfather           8.4        5893
# 2                  Whiplash           8.3        4254
# 3                Fight Club           8.3        9413
# 4              Pulp Fiction           8.3        8428
#
#                                                 cast  \
# 0  Tim Robbins Morgan Freeman Bob Gunton Clancy B...
# 1  Marlon Brando Al Pacino James Caan Richard S. ...
# 2  Miles Teller J.K. Simmons Melissa Benoist Aust...
# 3  Edward Norton Brad Pitt Meat Loaf Jared Leto H...
# 4  John Travolta Samuel L. Jackson Uma Thurman Br...
#
#                                                 crew              director
# 0  [{'name': 'Thomas Newman', 'gender': 2, 'depar...        Frank Darabont
# 1  [{'name': 'Francis Ford Coppola', 'gender': 2,...  Francis Ford Coppola
# 2  [{'name': 'Terri Taylor', 'gender': 1, 'depart...       Damien Chazelle
# 3  [{'name': 'Arnon Milchan', 'gender': 2, 'depar...         David Fincher
# 4  [{'name': 'Quentin Tarantino', 'gender': 2, 'd...     Quentin Tarantino
