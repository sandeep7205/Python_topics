# %% [markdown]
# # String

# %% [markdown]
# Question 1: Creating Strings
#
# Assign the phrase "Hello, World!" to a variable named greeting. How do you create a string in Python?
#
# Hint: Strings can be created by enclosing text in single (') or double (") quotes.

# %%
greeting = "Hello World!"
weather = "Today's weather is rainy"

print(greeting)
print(weather)
# Out:
# Hello World!
# Today's weather is rainy

# %% [markdown]
# Question 2: String Length Concept
#
# How can you find out the number of characters in a string? Consider the string Python is fun!.
#
# Hint: Think about how you could count each character, including spaces, to determine the string's length.

# %%
get_string = "Python is fun!"
print("Length of - Python is fun! - ", len(get_string))
# Out:
# Length of - Python is fun! -  14

# %% [markdown]
# Question 3: Concatenating Strings
#
# How do you join two strings together? Join the strings Hello and World with a space between them.
#
# Hint: You can use the + operator to add strings together, remembering to include spaces as needed.

# %%
str1 = "Hello"
str2 = "Sandeep"

print(str1,str2)
print(str1 + " " + str2)
print(" ".join([str1, str2]))
print("{} {}".format(str1, str2))
# Out:
# Hello Sandeep
# Hello Sandeep
# Hello Sandeep
# Hello Sandeep

# %% [markdown]
# Question 4: Using Newline Characters
#
# What special character is used to create a new line in a string? Demonstrate by creating a string that spans multiple lines.
#
# Hint: The newline character \n can be used within a string to move part of the string to a new line.

# %%
content = "Dear sir/ma'am \n My Name is Sandeep Kumar Mishra, I have joinned Data Engineering Self Packed course. I ave no access to the Challenges section. \n Please help to get the access to challenge section for my betterment. \n Thanks & Regards \n Sandeep Kumar Mishra"

print(content)
# Out:
# Dear sir/ma'am
#  My Name is Sandeep Kumar Mishra, I have joinned Data Engineering Self Packed course. I ave no access to the Challenges section.
#  Please help to get the access to challenge section for my betterment.
#  Thanks & Regards
#  Sandeep Kumar Mishra

# %% [markdown]
# Question 5: Accessing String Characters
#
# How can you access a specific character in a string? Try to access the first character of the string Data.
#
# Hint: Each character in a string has an index, starting with 0 for the first character.

# %%
my_name = "Sandeep Kumar Mishra"

print(my_name[6])
# Out:
# p

# %% [markdown]
# Question 6: Understanding String Slicing
#
# What is string slicing, and how can it be used to extract a portion of a string? Extract World from Hello, World!.
#
# Hint: String slicing involves specifying a range of indices to create a substring, using the syntax [start:end].
#
#
# ![image.png](attachment:image.png)

# %%
var="HELLO PYTHON"
print ("var:",var)
print(var[7])  
print(var[-5])  
print ("var[3:8]:", var[3:8])
print ("var[-9:-4]:", var[-9:-4])
print ("var[6:]:", var[6:])
print ("var[:5]:", var[:5])
print ("var[:]:", var[:])
print ("var[-1:7]:", var[-1:7])
print ("var[7:0]:", var[7:0])
# Out:
# var: HELLO PYTHON
# Y
# Y
# var[3:8]: LO PY
# var[-9:-4]: LO PY
# var[6:]: PYTHON
# var[:5]: HELLO
# var[:]: HELLO PYTHON
# var[-1:7]:
# var[7:0]:

# %% [markdown]
# Question 7: Immutability of Strings
#
# Can you change a character in a string once it has been created? Try to change Hello to Jello.
#
# Hint: Consider the property of strings regarding changes after their creation.

# %%
var="HELLO"
var[0] = "J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 var="HELLO"
# ----> 2 var[0] = "J"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Question 8: The Significance of Escape Characters
#
# Besides \n, what are other escape characters, and what do they do? Give an example using \t (tab).
#
# Hint: Escape characters allow you to include special characters in a string that would otherwise be difficult to type directly.

# %%
# ignore \
s = 'This string will not include \
backslashes or newline characters.'
print (s)

# escape backslash
s=s = 'The \\character is called backslash'
print (s)

# escape single quote
s='Hello \'Python\''
print (s)

# escape double quote
s="Hello \"Python\""
print (s)

# escape \b to generate ASCII backspace
s='Hel\blo'
print (s)

# ASCII Bell character
s='Hello\a'
print (s)

# newline
s='Hello\nPython'
print (s)

# Horizontal tab
s='Hello\tPython'
print (s)

# form feed
s= "hello\fworld"
print (s)

# Octal notation
s="\101"
print(s)

# Hexadecimal notation
s="\x41"
print (s)
# Out:
# This string will not include backslashes or newline characters.
# The \character is called backslash
# Hello 'Python'
# Hello "Python"
# Helo
# Hello
# Hello
# Python
# Hello	Python
# helloworld
# A
# A

# %% [markdown]
# Question 9: String Concatenation Without Operators
#
# Without using the + operator, how else might you combine strings in Python? Think about using string literals next to each other.
#
# Hint: Placing string literals next to each other in code will automatically concatenate them.

# %%
string_para = "Sandeep" ' ' "Mishra"

print(string_para)
# Out:
# Sandeep Mishra

# %% [markdown]
# Question 10: Incorporating Variables in Strings
#
# Before the introduction of string formatting or f-strings, how could you include variables in strings? Create a string that includes the integer variable age = 25.
#
# Hint: Consider concatenation or converting numbers to strings with the str() function to include them in a string.

# %%
age = 25 

message = "Your age is " + str(age)

print(message)
# Out:
# Your age is 25
