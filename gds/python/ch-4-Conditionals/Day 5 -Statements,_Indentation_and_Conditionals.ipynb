# %% [markdown]
# # Understanding Operators in Python
#
# ## Introduction to Operators
#
# Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.
#
# ## Types of Operators in Python
#
# ### Arithmetic Operators
# - **Addition (`+`)**: Adds two operands. Example: `x + y`
# - **Subtraction (`-`)**: Subtracts the second operand from the first. Example: `x - y`
# - **Multiplication (`*`)**: Multiplies two operands. Example: `x * y`
# - **Division (`/`)**: Divides the first operand by the second. Example: `x / y`
# - **Modulus (`%`)**: Returns the remainder when the first operand is divided by the second. Example: `x % y`
# - **Exponentiation (`**`)**: Raises the first operand to the power of the second. Example: `x ** y`
# - **Floor Division (`//`)**: Division that results in whole number adjusted to the left in the number line. Example: `x // y`
#
# ### Comparison Operators
# - **Greater than (`>`)**: True if the left operand is greater than the right. Example: `x > y`
# - **Less than (`<`)**: True if the left operand is less than the right. Example: `x < y`
# - **Equal to (`==`)**: True if both operands are equal. Example: `x == y`
# - **Not equal to (`!=`)**: True if operands are not equal. Example: `x != y`
# - **Greater than or equal to (`>=`)**: True if the left operand is greater than or equal to the right. Example: `x >= y`
# - **Less than or equal to (`<=`)**: True if the left operand is less than or equal to the right. Example: `x <= y`
#
# ### Logical Operators
# - **AND**: True if both operands are true. Example: `x and y`
# - **OR**: True if either of the operands is true. Example: `x or y`
# - **NOT**: True if the operand is false. Example: `not x`
#
# ### Assignment Operators
# - **Assign (`=`)**: Assigns value from right side to the left side operand. Example: `x = y`
# - **Add AND (`+=`)**: It adds the right operand to the left operand and assigns the result to the left operand. Example: `x += y`
# - **Subtract AND (`-=`)**: It subtracts the right operand from the left operand and assigns the result to the left operand. Example: `x -= y`
# - ... (continue with other assignment operators)
#
# ### Identity Operators
# - **is**: True if two variables point to the same object. Example: `x is y`
# - **is not**: True if two variables do not point to the same object. Example: `x is not y`
#
# ### Membership Operators
# - **in**: True if the value is found in the sequence. Example: `x in y`
# - **not in**: True if the value is not found in the sequence. Example: `x not in y`

# %% [markdown]
# # <u> Conditional Statements </u>
#
# * <code>if</code> Statements in Python allows us to tell the computer to perform alternative actions based on a certain set of results.
#
#
# * Verbally, we can imagine we are telling the computer:"Hey if this case happens, perform some action"
#
#
# * We can then expand the idea further with <code>elif</code> and <code>else</code> statements, which allow us to tell the computer: "Hey if this case happens, perform some action. Else, if another case happens, perform some other action. Else, if *none* of the above cases happened, perform this action."
#
#
# * Let's go ahead and look at the syntax format for <code>if</code> statements to get a better idea of this:
#
#     if case1:
#         perform action1
#     elif case2:
#         perform action2
#     else:
#         perform action3

# %%
if case1:
  # do some action
elif case5:
    # another action
elif case2:
  # do some another action
else:
  # do some yet another action
# Out:
#   File "C:\Users\Shubhankit\AppData\Local\Temp\ipykernel_24920\3707342238.py", line 3
#     elif case5:
#     ^
# IndentationError: expected an indented block

# %%
x=20   # Statement 1 - Assignment statement

if x == 20 :
  print('x is greater than 10!')
  print(f'x is {x}')
# Out:
# x is greater than 10!
# x is 20

# %%
number = 10
if number > 5:
    print("The number is greater than 5.")
# Out:
# The number is greater than 5.

# %%
name = "Alice"
if 'n' in name:
    print("Your name contains the letter A.")

# %%
x = 15
if x > 10:
    print("x is greater than 10.")

if x % 2 != 0:
    print("x is even.")

if x % 5 == 0:
    print("x is divisible by 5.")
# Out:
# x is greater than 10.
# x is even.
# x is divisible by 5.

# %%
age = 20
has_license = True
if age >= 18 and has_license:
    print("You can drive a car.")
# Out:
# You can drive a car.

# %%
num = 17


if num > 20:
    
    print("Number is greater than 20.")
    
    if num % 2 == 1:
        
        print("Number is odd.")

# %%
## Else Statements

# %%
age=13

if age >= 18:
    
    print("You are eligible to vote.")
    
else:
    
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %%
number = 7
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is odd.

# %%
user_input = input("Enter a number: ")


num = int(user_input)


if num > 0:
    print("The number is positive.")
else:
    print("The number is negative or zero.")
# Out:
# Enter a number: 1
# The number is positive.

# %%
fruits = ["apple", "banana", "cherry"]


if "mango" in fruits:
    
    print("Mango is in the fruit list.")
else:
    print("Mango is not in the fruit list.")
# Out:
# Mango is not in the fruit list.

# %%
temperature = 32

if temperature > 25:
    
    if temperature > 30:
        
        print("It's a very hot day.")
        
    else:
        print("It's a warm day.")
        
else:
    print("It's not a hot day.")
# Out:
# It's a very hot day.

# %% [markdown]
# ### ELIF STATEMENTS
#
#
#
# The elif Statement
# elif (short for else if) is used to check multiple expressions for True and execute a block of code as soon as one of the conditions evaluates to True. Similar to else, the elif statement is optional. However, unlike else, for which there can be at most one statement, there can be an arbitrary number of elif statements following an if.

# %%
score = 82

if score >= 90:
    print("Grade: A")
if score >= 80:
    print("Grade: B")
if score >= 70:
    print("Grade: C")
if score >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Grade: B
# Grade: C
# Grade: D

# %%
hour = 18
if hour < 12:
    print("Good morning!")
elif hour < 18:
    print("Good afternoon!")
else:
    print("Good evening!")
# Out:
# Good evening!

# %%
choice = input("Enter your choice (1, 2, or 3): ")
if choice == '1':
    print("You chose option 1.")
elif choice == '2':
    print("You chose option 2.")
elif choice == '3':
    print("You chose option 3.")
else:
    print("Invalid choice.")
# Out:
# Enter your choice (1, 2, or 3): 14
# Invalid choice.

# %%
a=3
b=3

if a>b:
    print("a is greater")
    
elif a==b:
    print("both are equal")
    
else:
    print("b is greater")
# Out:
# both are equal

# %%
# check for login , where is login 

# if login in true, take user name as a variable.
# if login not true, set username to none


#now,. if user name is not none, welcome the user


#else, ask them to sign in


login=False

if login:
    
    user_name=input("Enter the user name")
    
elif login:
    
    user_name=None
    
if user_name is None:
    
    print("please sign in first")
    
else:
    print(f"welcome {user_name} ")
# Out:
# please sign in first

# %%
# rohit and virat are two batsman,  a batsmen is better if his avg and greater, 
# his max score is greater and total runs are more

r=[23,445,655,23,545,66,5456,65,23,54]

v=[33,56,2324,545,232,55,232,55,21,1,43,5,654]

#who is a better batsmen

r_sum=sum(r)
v_sum=sum(v)

r_avg=sum(r)/len(r)

v_avg=sum(v)/len(v)


r_max=max(r)
v_max=max(v)


if r_sum > v_sum and r_avg>v_avg and r_max>v_max:
    print("rohit is better")
    
else:
    print("I cant decide, but i am a fan of virat, so virat will be better")
# Out:
# rohit is better

# %% [markdown]
# ## <u>Truthy & Falsy</u>
#
# ### A "truthy" value will satisfy the check performed by if or while statements. We use "truthy" and "falsy" to differentiate from the boolean values True and False.

# %% [markdown]
# ### All values are considered "truthy" except for the following, which are "falsy":
#
# * <code>None</code>
# * <code>False</code>
# * <code>0</code>
# * <code>0.0</code>
# * <code>[]</code> - an empty <code>list</code>
# * <code>{}</code> - an empty <code>dict</code>
# * <code>()</code> - an empty <code>tuple</code>
# * <code>''</code> - an empty <code>str</code>

# %%
# Consider the following statement

if [1]:
  print("What do you say?")
else:
  print("I have nothing to say")
# Out:
# What do you say?

# %%
#booking a ticket


first_name='shubhanit'

last_name="sdfkjdv"

age=None

gender='M'

if age:
    print("okay")

else:
    print("age needed")
# Out:
# age needed

# %%
if 0:
    print("its working")

# %%
if [None]:
    
  print("Well I had a really bad day!")

else:
    
  print("Come on you aced your test.")
# Out:
# Well I had a really bad day!

# %%
if {1:2,3:4}:
  print("This is True")
else:
  print("This is False")
# Out:
# This is True
