# %%
def multiply(a, b):
    return a * b

result = multiply("5", 5)
print("Result:", result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 def multiply(a, b):
#       2     return a * b
# ----> 4 result = multiply("5", "6")
#       5 print("Result:", result)
#
# Cell In[1], line 2, in multiply(a, b)
#       1 def multiply(a, b):
# ----> 2     return a * b
#
# TypeError: can't multiply sequence by non-int of type 'str'
