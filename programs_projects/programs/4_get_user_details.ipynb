# %% [markdown]
# # How to Get the Current Username in Python

# %%
import os
import getpass

# print(f"getpass module functions: {dir(getpass)}")

# print("\n\n----------getpass module----------")
# user_name = getpass.getuser()
# pass_word = getpass.getpass("Enter password: ")
 
# print("User name: ", user_name)
# print("Your password :", pass_word)
# print("----------------------------------\n\n")



# print(f"os module functions: {dir(os)}")
# print("\n\n----------os module----------")
# print(os.getlogin())  # Get current user login name
# print(os.listdir('.'))  # List files in the current directory
# print(os.environ['HOME'])  # Get home directory
# print(os.path.abspath('.'))  # Get absolute path of current directory
# print(os.path.join(os.getcwd(), '4_get_user_details.ipynb'))  # Join paths
# # print(os.path.exists('4_get_user_details.ipynb'))  # Check if a file exists
# print("----------------------------------\n\n")




# May raise OSError if no terminal is attached
try:
    print("os.getlogin():", os.getlogin())
    username = os.environ.get("USERNAME") or os.environ.get("USER")
    print(f"os module: {username}")
except Exception as e:
    print("os.getlogin() failed:", e)

# Recommended way
print("getpass.getuser():", getpass.getuser())
# Out:
# os.getlogin(): sandeepkumarmishra
# os module: sandeepkumarmishra
# getpass.getuser(): sandeepkumarmishra
