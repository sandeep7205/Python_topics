# %% [markdown]
# # How to find out the version of Python you are using

# %%
#Check from inside your Python program

import sys

print(sys.version)
print(f"You're using Python version {sys.version}")
# Out:
# 3.10.12 (main, May 27 2025, 17:12:29) [GCC 11.4.0]
# You're using Python version 3.10.12 (main, May 27 2025, 17:12:29) [GCC 11.4.0]

# %%
#Use platform module for simpler info

import platform

# print(platform.python_version_tuple())
print(f"You're using Python version {platform.python_version()}")
# Out:
# ('3', '10', '12')
# You're using Python version 3.10.12
