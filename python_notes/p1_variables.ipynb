# %% [markdown]
# ## Variables
# ##### Creating Variables, Casting a Variable & Get the Type of a Variable

# %%
# x = 5
x = 5.78
# x = "SKM"
print("x is [", x,"] & it's type is [", type(x), "]")

y = str(x)
# y = int(x)
# y = float(x)
print("y is [", y,"] & it's type is [", type(y), "]")

# %% [markdown]
# #### Legal variable names:
# ```
# myvar = "John"
# my_var = "John"
# _my_var = "John"
# myVar = "John"
# MYVAR = "John"
# myvar2 = "John"
# ```
# #### Multi Words Variable Names
# ```
# Camel Case ->  myVariableName = "John"
# Pascal Case -> MyVariableName = "John"
# Snake Case ->  my_variable_name = "John"
# ```
# #### Assign Multiple Values
# ```
# x, y, z = "Orange", "Banana", "Cherry"
# ```
# #### One Value to Multiple Variables
# ```
# x = y = z = "Orange"
# ```
# #### Unpack a Collection

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x, y, z)

x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# apple banana cherry
# Python is awesome

# %% [markdown]
# #### Output Variables

# %%
print(3 ,"7") # 3 7
print(3 + 7) #10
# print(3 + "7") #TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### Global Variables

# %%
x = "awesome" #global variables
def myfunc():
#   global x
  x = "fantastic" # local becomes global variables
  print("Python is " + x)
myfunc()
print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# #### The global Keyword
# - If we use the `global` keyword, the variable belongs to the global scope or we change a global variable inside a function

# %%
# the variable  'x' belongs to the global scope:
def myfunc():
  global x
  x = "fantastic"

myfunc()
print("Python is " + x)
# Out:
# Python is fantastic

# %%
# change the value of a global variable inside a function.

x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()
print("Python is " + x)
# Out:
# Python is fantastic
