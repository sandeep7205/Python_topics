# %% [markdown]
# # Data Types
# #### Built-in Data Types
# ```
# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range
# Mapping Type:	dict
# Set Types:	set, frozenset
# Boolean Type:	bool
# Binary Types:	bytes, bytearray, memoryview
# None Type:	NoneType
# ```
# #### Setting the Data Type

# %%
x = "Hello World"	#str	
print("Value:", x, " →→→ Type:", type(x))

x = 20	#int	
print("Value:", x, " →→→ Type:", type(x))

x = 20.5	#float	
print("Value:", x, " →→→ Type:", type(x))

x = 1j	#complex	
print("Value:", x, " →→→ Type:", type(x))

x = ["apple", "banana", "cherry"]	#list	
print("Value:", x, " →→→ Type:", type(x))

x = ("apple", "banana", "cherry")	#tuple	
print("Value:", x, " →→→ Type:", type(x))

x = range(6)	#range	
print("Value:", x, " →→→ Type:", type(x))

x = {"name" : "John", "age" : 36}	#dict	
print("Value:", x, " →→→ Type:", type(x))

x = {"apple", "banana", "cherry"}	#set	
print("Value:", x, " →→→ Type:", type(x))

x = frozenset({"apple", "banana", "cherry"})	#frozenset	
print("Value:", x, " →→→ Type:", type(x))

x = True	#bool	
print("Value:", x, " →→→ Type:", type(x))

x = b"Hello"	#bytes	
print("Value:", x, " →→→ Type:", type(x))

x = bytearray(5)	#bytearray	
print("Value:", x, " →→→ Type:", type(x))

x = memoryview(bytes(5))	#memoryview	
print("Value:", x, " →→→ Type:", type(x))

x = None	#NoneType
print("Value:", x, " →→→ Type:", type(x))
# Out:
# Value: Hello World  →→→ Type: <class 'str'>
# Value: 20  →→→ Type: <class 'int'>
# Value: 20.5  →→→ Type: <class 'float'>
# Value: 1j  →→→ Type: <class 'complex'>
# Value: ['apple', 'banana', 'cherry']  →→→ Type: <class 'list'>
# Value: ('apple', 'banana', 'cherry')  →→→ Type: <class 'tuple'>
# Value: range(0, 6)  →→→ Type: <class 'range'>
# Value: {'name': 'John', 'age': 36}  →→→ Type: <class 'dict'>
# Value: {'apple', 'cherry', 'banana'}  →→→ Type: <class 'set'>
# Value: frozenset({'apple', 'cherry', 'banana'})  →→→ Type: <class 'frozenset'>
# Value: True  →→→ Type: <class 'bool'>
# Value: b'Hello'  →→→ Type: <class 'bytes'>
# Value: bytearray(b'\x00\x00\x00\x00\x00')  →→→ Type: <class 'bytearray'>
# Value: <memory at 0x7890aa619780>  →→→ Type: <class 'memoryview'>
# Value: None  →→→ Type: <class 'NoneType'>

# %% [markdown]
# #### Setting the Specific Data Type

# %%
x = str("Hello World")	
print("Value:", x, " →→→ Type:", type(x))

x = int(20)		
print("Value:", x, " →→→ Type:", type(x))

x = float(20.5)		
print("Value:", x, " →→→ Type:", type(x))

x = complex(1j)		
print("Value:", x, " →→→ Type:", type(x))

x = list(("apple", "banana", "cherry"))		
print("Value:", x, " →→→ Type:", type(x))

x = tuple(("apple", "banana", "cherry"))		
print("Value:", x, " →→→ Type:", type(x))

x = range(6)		
print("Value:", x, " →→→ Type:", type(x))

x = dict(name="John", age=36)		
print("Value:", x, " →→→ Type:", type(x))

x = set(("apple", "banana", "cherry"))		
print("Value:", x, " →→→ Type:", type(x))

x = frozenset(("apple", "banana", "cherry"))		
print("Value:", x, " →→→ Type:", type(x))

x = bool(5)		
print("Value:", x, " →→→ Type:", type(x))

x = bytes(5)		
print("Value:", x, " →→→ Type:", type(x))

x = bytearray(5)	
print("Value:", x, " →→→ Type:", type(x))

x = memoryview(bytes(5))	
print("Value:", x, " →→→ Type:", type(x))
# Out:
# Value: Hello World  → Type: <class 'str'>
# Value: 20  → Type: <class 'int'>
# Value: 20.5  → Type: <class 'float'>
# Value: 1j  → Type: <class 'complex'>
# Value: ['apple', 'banana', 'cherry']  → Type: <class 'list'>
# Value: ('apple', 'banana', 'cherry')  → Type: <class 'tuple'>
# Value: range(0, 6)  → Type: <class 'range'>
# Value: {'name': 'John', 'age': 36}  → Type: <class 'dict'>
# Value: {'apple', 'cherry', 'banana'}  → Type: <class 'set'>
# Value: frozenset({'apple', 'cherry', 'banana'})  → Type: <class 'frozenset'>
# Value: True  → Type: <class 'bool'>
# Value: b'\x00\x00\x00\x00\x00'  → Type: <class 'bytes'>
# Value: bytearray(b'\x00\x00\x00\x00\x00')  → Type: <class 'bytearray'>
# Value: <memory at 0x7890aa618e80>  → Type: <class 'memoryview'>

# %% [markdown]
# ---
# ## Numbers
# ``` Note: We cannot convert complex numbers into another number type.```

# %%
# int
x = 1
y = 35656222554887711
z = -3255522
print(type(x), type(y), type(z))

# float
x = 1.10
y = 1.0
z = -35.59
print(type(x), type(y), type(z))

# float
x = 35e3
y = 12E4
z = -87.7e100
print(type(x), type(y), type(z))

# complex
x = 3+5j
y = 5j
z = -5j
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'int'> <class 'int'>
# <class 'float'> <class 'float'> <class 'float'>
# <class 'float'> <class 'float'> <class 'float'>
# <class 'complex'> <class 'complex'> <class 'complex'>

# %% [markdown]
# #### Type Conversion

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print("Value:", a, " →→→ Type:", type(a))
print("Value:", b, " →→→ Type:", type(b))
print("Value:", c, " →→→ Type:", type(c))
# Out:
# Value: 1.0  →→→ Type: <class 'float'>
# Value: 2  →→→ Type: <class 'int'>
# Value: (1+0j)  →→→ Type: <class 'complex'>

# %% [markdown]
# #### Random Number

# %%
import random # random module

print(random.random()) # between 0-1 number only
print(random.randrange(1, 1000000000)) # int number only
print(random.uniform(1, 10)) # float number only
# Out:
# 0.33993805277285916
# 319683928
# 5.630823996321081

# %% [markdown]
# ---
# ## Strings

# %%
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)

# %% [markdown]
# #### Strings are Arrays

# %%
a = "Hello, World!"
print(a[1])

# %% [markdown]
# #### Looping Through a String

# %%
for x in a:
  print(x)

print(len(a)) #String Length

# %% [markdown]
# #### Check String

# %%
txt = "The best things in life are free!"
print("free" in txt)

txt = "The best things in life are free!"
print("expensive" not in txt)

# %% [markdown]
# #### Slicing Strings

# %%
b = "Hello, World!"
print(b[2:5]) # start point index - 2 &  end point index - 5  
print(b[:5]) # start point index - 0 &  end point index - 5  
print(b[2:]) # start point index - 2 &  end point index - end
print(b[-5:-2]) # From: "o" in "World!" (position -5) - To, but not included: "d" in "World!" (position -2):

# %% [markdown]
# #### Modify Strings

# %%
a = "  Hello, World!  "
print(a.upper())
print(a.lower())
print(a.strip()) #removes any whitespace from the beginning or the end

# %% [markdown]
# #### Replace Strings

# %%
a = "Hello, World!"
print(a.replace("H", "J"))

# %% [markdown]
# #### Split Strings

# %%
print(a.split(",")) # returns ['Hello', ' World!']

# %% [markdown]
# #### String Concatenation

# %%
a = "Hello"
b = "World"
c = a + b
print(c)

# %% [markdown]
# #### Format - Strings [f-strings]

# %%
price = 36
txt = f"My name is John, I am {price}"    #A placeholder can contain variables, operations, functions, and modifiers to format the value.
print(txt)
txt2 = f"The price is {price:.2f} dollars"  #A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals
print(txt2)
txt3 = f"The price is {price * 3} dollars" 
print(txt3)

# %% [markdown]
# ---
# ## Booleans

# %%
print(10 > 9, 10 == 9, 10 < 9)
print(bool(-1), bool(10.9), bool("Hello"))
print(bool(False), bool(None), bool(0), bool(""), bool(()), bool([]), bool({}))
x = 200
print(isinstance(x, int))

# %% [markdown]
# ---
# ## Operators

# %%
x = 5	
x += 3 #8
# x -= 3 #2	
# x *= 3 #15	
# x /= 3	#1.67
# x %= 3	#1.67
# x //= 3	#1	
# x **= 3	#125	
# x &= 3	#1
# x |= 3	#7
# x ^= 3	#6
# x >>= 3		#0
# x <<= 3	#40
print(x)
# Out:
# 8
