# %% [markdown]
# ## Tuples
#
# - Tuples are used to store multiple items in a single variable.
# - A tuple is a collection which is `ordered, unchangeable, and allow duplicate values`.
# - Tuples are written with round `()` brackets.

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print("tuple with duplicate values - ", thistuple)

print("[0]: first index of tuple - ", thistuple[0])

#Print the number of items in the tuple
print("len(): length of tuple - ", len(thistuple)) 

thistuple_new = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print("tuple(()) constructor - ", thistuple_new)
# Out:
# tuple with duplicate values -  ('apple', 'banana', 'cherry', 'apple', 'cherry')
# [0]: first index of tuple -  apple
# len(): length of tuple -  5
# tuple(()) method -  ('apple', 'banana', 'cherry')

# %% [markdown]
# #### Create Tuple With One Item
#
# - To create a tuple with only one item, you have to add a comma `,` after the item, otherwise Python will not recognize it as a tuple.

# %%
thistuple = ("apple",)
print("comma ',' ('apple',): need for single item - ", type(thistuple)) # tuples are defined as objects with the data type 'tuple':

#NOT a tuple
thistuple = ("apple")
print("without comma ',' ('apple'): not a tuple - ",type(thistuple))
# Out:
# comma ',' ('apple',): need for single item -  <class 'tuple'>
# without comma ',' ('apple'): not a tuple -  <class 'str'>

# %% [markdown]
# #### Tuple Items - Data Types
# - Tuple items can be of any data type:

# %%
mytuple = (90, 45.67, 3j+6, "680hkh", True)
print("tuple contains different data types - ", mytuple)
# Out:
# tuple contains different data types -  (90, 45.67, (6+3j), '680hkh', True)

# %% [markdown]
# ### Access Tuple

# %% [markdown]
# #### Access Tuple Items

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple)

print("second item in the tuple: - ", thistuple[1])
print("Negative Indexing: last item in the tuple - ", thistuple[-1])

# Range of Indexes:
print("Range of Indexes:[1:5] second to fifth item in the tuple: - ",thistuple[1:5]) # will start at index 2 (included) and end at index 5 (not included).
print("[:5]: returns the items from the beginning to, but NOT included 5th index - ", thistuple[:5])
print("[3:]:returns the items from 3rd index and to the end - ", thistuple[3:])

# Range of Negative Indexes
print("Negetive Range of Indexes: from index -7 (included) to index -3 (excluded) [-7:-3] - ", thistuple[-7:-3])
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# second item in the tuple: -  banana
# Negative Indexing: last item in the tuple -  mango
# Range of Indexes:[1:5] second to fifth item in the tuple: -  ('banana', 'cherry', 'orange', 'kiwi')
# [:5]: returns the items from the beginning to, but NOT included 5th index -  ('apple', 'banana', 'cherry', 'orange', 'kiwi')
# [3:]:returns the items from 3rd index and to the end -  ('orange', 'kiwi', 'melon', 'mango')
# Negetive Range of Indexes: from index -7 (included) to index -3 (excluded) [-7:-3] -  ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# #### Check if Item Exists
# - To determine if a specified item is present in a tuple use the in keyword:

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple)

if "cherry" in thistuple:
    print("cherry exists in tuple")
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# cherry exists in tuple

# %% [markdown]
# ### Update Tuples
# - Tuples are `unchangeable, or immutable`
#     - Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created with some workarounds.
#     - But there is a workaround. You can convert the `tuple into a list, change the list, and convert the list back into a tuple`.

# %% [markdown]
# #### Change Tuple Values

# %%
# Convert the tuple into a list to be able to change the value in it:
x = ("apple", "banana", "cherry")
print("original Tuple - ", x)
#convert into a list:
y = list(x) 
print("Convert into a list() - ", y)
#edit the list:
y[1] = "kiwi"
print("add/replace item using index in list mode - ", y)
#convert it back into a tuple
x = tuple(y) 
print("Tuple after add/edit items - ", x)

print("\n------------\n")

y.append("orange") 
print("append(): value add to the converted list - ", y)

z = ("melon",) #Create a new tuple with the value "melon",
print("create a new tuple having single item with ',' - ",  z)

#add new tuple with old list (converted from tuple):
y += z 
y.extend(("mango",)) 
print("Add new tuple with list", y)

#remove "apple" from list
y.remove("apple") 
print("Remove th eitem from list", y)

print("Tuple before list convertion - ", x)
x = tuple(y)
print("Tuple after convertion of list  - ", x)

#The del keyword can delete the tuple completely:
del x
print("tuple deleted")
# Out:
# original Tuple -  ('apple', 'banana', 'cherry')
# Convert into a list() -  ['apple', 'banana', 'cherry']
# add/replace item using index in list mode -  ['apple', 'kiwi', 'cherry']
# Tuple after add/edit items -  ('apple', 'kiwi', 'cherry')
#
# ------------
#
# append(): value add to the converted list -  ['apple', 'kiwi', 'cherry', 'orange']
# create a new tuple having single item with ',' -  ('melon',)
# Add new tuple with list ['apple', 'kiwi', 'cherry', 'orange', 'melon', 'mango']
# Remove th eitem from list ['kiwi', 'cherry', 'orange', 'melon', 'mango']
# Tuple before list convertion -  ('apple', 'kiwi', 'cherry')
# Tuple after convertion of list  -  ('kiwi', 'cherry', 'orange', 'melon', 'mango')
# tuple deleted

# %% [markdown]
# #### Unpack Tuples
#
# - When we create a tuple, we normally assign values to it. This is called `packing` a tuple:
# `fruits = ("apple", "banana", "cherry")`
#
# - But, in Python, we are also allowed to extract the values back into variables. This is called `unpacking`:
# `(green, yellow, red) = fruits`
#
# > Note: The number of variables must match the number of values in the tuple, if not, you must use an asterisk to collect the remaining values as a list.
#
#
# - Using Asterisk `*`
#     - If the number of variables is less than the number of values, you can add an * to the variable name and the values will be assigned to the variable as a list:
#     - If the asterisk is added to another variable name than the last, Python will assign values to the variable until the number of values left matches the number of variables left.

# %%
fruits = ("apple", "banana", "cherry")
print("Packing: Assign tuple values to a variable - ", fruits)

#Unpacking a tuple:
(green, yellow, red) = fruits
print("UnPacking: Index 0 / Value 1 - ", green)
print("UnPacking: Index 1 / Value 2 - ", yellow)
print("UnPacking: Index 2 / Value 3 - ", red)

print("\n------------\n")

#Using Asterisk[*] Assign the rest of the values as a list called "red":
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")
print("Tuple - ", fruits)
print("\n--add * to last variable--\n")
(green, yellow, *red) = fruits
print("UnPacking: Index 0 / Value 1 - ", green)
print("UnPacking: Index 1 / Value 2 - ", yellow)
print("UnPacking '*': Index 2 / Value 3 to last index/value as list - ", red)
print("\n--add * before last variable--\n")
(green, *yellow, red) = fruits
print("UnPacking: Index 0 / Value 1 - ", green)
print("UnPacking '*': Index 1 / Value 2 to last index 3 / value 4 as list - ", yellow)
print("UnPacking: Index 4 / Value 5  - ", red)
# Out:
# Packing: Assign tuple values to a variable -  ('apple', 'banana', 'cherry')
# UnPacking: Index 0 / Value 1 -  apple
# UnPacking: Index 1 / Value 2 -  banana
# UnPacking: Index 2 / Value 3 -  cherry
#
# ------------
#
# Tuple -  ('apple', 'banana', 'cherry', 'strawberry', 'raspberry')
#
# --add * to last variable--
#
# UnPacking: Index 0 / Value 1 -  apple
# UnPacking: Index 1 / Value 2 -  banana
# UnPacking '*': Index 2 / Value 3 to last index/value as list -  ['cherry', 'strawberry', 'raspberry']
#
# --add * before last variable--
#
# UnPacking: Index 0 / Value 1 -  apple
# UnPacking '*': Index 1 / Value 2 to last index 3 / value 4 as list -  ['banana', 'cherry', 'strawberry']
# UnPacking: Index 4 / Value 5  -  raspberry

# %% [markdown]
# #### Loop Tuples
# - You can loop through the `tuple items` by using a `for & while loop`.

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")
print("Tuple - ", fruits)

print("\n--Iterate through the items and print the values using for loop--\n")
for x in fruits:
  print(x)

print("\n--Print all items by referring to their index number: with range(len(Tuple)) --\n")

print("len(): Tuple length - ", len(fruits))
print("range(0, len(tuple)): Range of Tuple length - ", range(len(fruits))) # range(start [default 0], stop, step)

for i in range(len(fruits)):
  print(fruits[i])

print("\n--Print all items, using a while loop to go through all the index numbers: with len(tuple)--\n")

i = 0
while i < len(fruits):
  print(f"index {i} value is {fruits[i]}")
  i += 1
# Out:
# Tuple -  ('apple', 'banana', 'cherry', 'strawberry', 'raspberry')
#
# --Iterate through the items and print the values using for loop--
#
# apple
# banana
# cherry
# strawberry
# raspberry
#
# --Print all items by referring to their index number: with range(len(Tuple)) --
#
# len(): Tuple length -  5
# range(0, len(tuple)): Range of Tuple length -  range(0, 5)
# apple
# banana
# cherry
# strawberry
# raspberry
#
# --Print all items, using a while loop to go through all the index numbers: with len(tuple)--
#
# index 0 value is apple
# index 1 value is banana
# index 2 value is cherry
# index 3 value is strawberry
# index 4 value is raspberry

# %% [markdown]
# #### Join Tuples
#
# - To join two or more tuples you can use the `+` operator:
# - To multiply the content of a tuple a given number of times, you can use the `*` operator:

# %%
#Join two tuples:
tuple1 = ("a", "b786" , 3j+8)
tuple2 = (1, "a", 3.89)
tuple3 = tuple1 + tuple2 
print("Join two tuples: using '+' - ", tuple3)

# Multiply the fruits tuple by 2:
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2
print("Multiply the fruits tuple by 2:using '*' - ", mytuple)
# Out:
# Join two tuples: using '+' -  ('a', 'b786', (8+3j), 1, 'a', 3.89)
# Multiply the fruits tuple by 2:using '*' -  ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %% [markdown]
# #### 📋 Python Tuple Methods
#
# | Method        | Description                                                                 |
# |--------------|-----------------------------------------------------------------------------|
# | `count()`   | Returns the number of times a specified value occurs in a tuple                                       |
# | `index()`    | Searches the tuple for a specified value and returns the position of where it was found |

# %%
tuple1 = ("a", "b", "786" , 3j+8)
tuple2 = (1, "a", 3.89)
tuple3 = tuple1 + tuple2 
print("tuples - ", tuple3)
print("count('a'): Tuple item occured - ", tuple3.count('a'))
print("index('a'): Tuple item first occurance index - ", tuple3.index('a'))
# Out:
# tuples -  ('a', 'b', '786', (8+3j), 1, 'a', 3.89)
# count('a'): Tuple item occured -  2
# index('a'): Tuple item first occurance index -  0
